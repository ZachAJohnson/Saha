# %% [markdown]
# # Saha code

# %% [markdown]
# Based on paper by [Seungtaek](https://iopscience.iop.org/article/10.1088/1361-6587/ac7ee8/pdf)
#
# #### Ionization Potential Depression (from continuum lowering)
# We assume some average ionization level $\bar{Z} \equiv n_e/n_0$ and also that the ionization is lower than 1 for simplicity.
#
# In atomic units, we have
# $$
# \Delta \chi = (\bar{Z} + 1)\sqrt{4 \pi \frac{\bar{Z} (\bar{Z}+1)n_0}{T_e}}
# $$
# Then the Saha equation is in the singly ionized limit is
# $$
# \frac{\bar{Z}^2 }{1-\bar{Z}} = \frac{2 g_1}{n_0 g_0} \left(\frac{m_e T_e}{2 \pi}\right)^{3/2} \exp \left[\beta (\chi_0 - \Delta \chi )\right].
# $$
# Where $g_0$ and $g_1$ are the degeneracy parameters for neutral and singly ionized species.
#
# #### Argon
# For argon this is $g_0=1$, and $g_1\approx 6$, which comes from the fact that S=1/2, L=1, so J={1/2, 3/2}, giving 2 + 4 = 6 total states that are approximately degenerate.
#
# #### Xenon
# I think it should be the same, as long as d-orbitals don't play a role...
#
#
# For ionization energies, see [NIST](https://physics.nist.gov/cgi-bin/ASD/ie.pl?spectra=Xe&units=1&at_num_out=on&el_name_out=on&seq_out=on&shells_out=on&level_out=on&e_out=0&unc_out=on&biblio=on)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from cycler import cycler


mpl.rcParams['lines.linewidth'] = 2.2
mpl.rcParams['axes.spines.right'] = True
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.labelsize'] = 14
mpl.rcParams['ytick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12
mpl.rcParams['lines.markersize'] = 8
mpl.rcParams['font.sans-serif'] = ['Arial', 'Tahoma', 'DejaVu Sans', 'Lucida Grande', 'Verdana']
mpl.rcParams['font.size'] = 12
mpl.rcParams['axes.grid'] = True
mpl.rcParams['grid.color'] = '#636363'
mpl.rcParams['grid.alpha'] = 0.12
mpl.rcParams['grid.linewidth'] = 0.7
mpl.rcParams['grid.linestyle'] = '-'
mpl.rcParams['axes.prop_cycle'] = cycler('color',  ['#0AB34F', '#bf009f', '#00abc3', '#8e92c5', '#cc7014', '#e32851'])
mpl.rcParams['legend.fancybox'] = True
mpl.rcParams['legend.framealpha'] = 0.6
mpl.rcParams['legend.fontsize'] = 10
mpl.rcParams['figure.figsize'] = 8, 4.9443
mpl.rcParams['figure.dpi'] = 100

from constants import *

# %%
from scipy.optimize import root, least_squares

@np.vectorize
def Δχ_func(Zbar, n0, Te): # in AU 
    return 1e-3#np.min( [ (Zbar+1) * np.sqrt(4*π * Zbar*(Zbar+1)*n0/Te) , χ0_AU] )

def leftminusrightsquare_saha(Zbar, n0, Te):
    Δχ = Δχ_func(Zbar, n0, Te)
    left_hand_side = Zbar**2/(1 - Zbar) 
    right_hand_side = 2/n0 * g1/g0 * (m_e*Te/(2*π))**(3/2) * np.exp( -(χ0_AU - Δχ)/Te )
    return (left_hand_side - right_hand_side)**2


@np.vectorize
def solve_Saha(Te, n0, Zbar_0=0.5, verbose=False):
    saha_LR = lambda Zbar: leftminusrightsquare_saha(Zbar, n0, Te) 
    ε = 1e-2
    sol =  least_squares(saha_LR, Zbar_0, bounds=(0,1), ftol=1e-10, xtol=1e-8, gtol=None, max_nfev = 1000)
    
    if sol.cost > 1e-8 or sol.success==False or sol.x<1e-10 or np.abs(Δχ_func(sol.x, n0, Te)-χ0_AU)<1e-2: #sol.grad > 1e-8 or sol.fun > 1e-8: 
        if verbose:
            print("Considered failure.")
            print(f"{sol.success}: Te={Te:0.3f}, n0={n0:0.1e}, Zbar_0={Zbar_0:0.3f}")
            print(sol)
        return np.nan, np.nan, sol
    return sol.x, Δχ_func(sol.x, n0, Te), sol

# %% [markdown]
# ## Xenon

# %%
element='Xe'
g1 = 6 
g0 = 1
χ0_eV = 12.1298437  # eV See 
χ0_AU = χ0_eV*eV_to_AU

n0_invcc = 1.86e20
n0_AU = n0_invcc*invcc_to_AU

# array
T_K_array = np.geomspace(5e3, 3e4, num=100)
Zbar_0_list = np.linspace(5e-6,1-1e-6, num=10)
Saha_list = [ solve_Saha(T_K_array*K_to_AU, n0_AU, Zbar_0=Zbar_0) for Zbar_0 in Zbar_0_list]

# %%
np.savetxt("Xenon_5bar_Saha.dat", np.array([T_K_array, Zbar_mean]).T, header='T[K]  Zbar  ', fmt='%10.6e', comments='')

# %%
fig, ax = plt.subplots(figsize=(10,6))

# colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

colors = plt.cm.plasma(np.linspace(0, 1,len(Saha_list))) #plt.cycler("color", plt.cm.jet(np.linspace(0,1,len(Saha_list))))



ax.set_ylabel(r"$\langle Z \rangle$")#,color=colors[0])
ax.set_xlabel("T [K]")
ax.set_xscale('log')

ax2 = ax.twinx()
# ax2.plot(T_K_array, Δχ_Saha*AU_to_eV,'--.',color=colors[1])
ax2.set_ylabel(r"$\Delta \chi$ [eV]")#,color=colors[1])

for i, (Zbar_0, Saha) in enumerate(zip(Zbar_0_list, Saha_list)):
    if i==0:
        try:
            ax.plot(T_K_array, Saha[0],'-' , color=colors[i], label=f'Initial guess, Zbar= {Zbar_0:0.3f}')
            ax2.plot(T_K_array, Saha[1]*AU_to_eV,'--' , color=colors[i], label=r'$\chi_0$')
        except TypeError:
            pass
            
    else:
        try:
            ax.plot(T_K_array, Saha[0],'-' , color=colors[i])#, label=f'Initial guess, Zbar= {Zbar_0:0.3f}')
            ax2.plot(T_K_array, Saha[1]*AU_to_eV,'--' , color=colors[i])
        except TypeError:
            pass

# ax2.plot(T_K_array, Δχ_Saha_1*AU_to_eV,'-' ,color=colors[1])

ax2.plot(T_K_array, np.ones_like(T_K_array)*χ0_AU*AU_to_eV,'-' ,color='k')
ax2.text(np.min(T_K_array)*1.2, 1.01*χ0_AU*AU_to_eV, r"$\chi_0$ = {0:0.1f} [eV]".format(χ0_AU*AU_to_eV), fontsize=12,
        verticalalignment='bottom')#, bbox=props)

# Adding a manual colorbar
sm = plt.cm.ScalarMappable(cmap='plasma', norm=plt.Normalize(vmin=0, vmax=1))
sm.set_array([])
fig.colorbar(sm, ax=[ax, ax2], orientation='vertical', label=r'$\langle Z\rangle^{\rm initial guess}$')

plt.subplots_adjust(right=0.7)

# text
props = dict(boxstyle='round', facecolor='white', alpha=0.5)
inset_text = f"{element} at n = {n0_invcc:0.2e} [1/cc]"
ax.text(0.15, 0.95, inset_text, transform=ax.transAxes, fontsize=12,
        verticalalignment='top', bbox=props)

ax.set_ylim(1e-7,1.2)
ax2.set_ylim(1e-3,1.2*χ0_AU*AU_to_eV)

ax.set_yscale('log')
ax2.set_yscale('log')
ax.legend()
# plt.tight_layout()

# ax.set_yscale('log')

# %%
# Fix nan, None issues...

Zbar_list = np.array([Saha[0] for Saha in Saha_list])
χ0_list   = np.array([Saha[1] for Saha in Saha_list])
Zbar_mean, Zbar_std = np.nanmean(Zbar_list,axis=0), np.nanstd(Zbar_list,axis=0) 
χ0_mean, χ0_std = np.nanmean(χ0_list,axis=0), np.nanstd(χ0_list,axis=0)

# %%
fig, ax = plt.subplots(figsize=(10,6))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

ax.set_ylabel(r"$\langle Z \rangle$",color=colors[0])
ax.set_xlabel("T [K]")
ax.set_xscale('log')

ax2 = ax.twinx()
ax2.set_ylabel(r"$\Delta \chi$ [eV]",color=colors[1])

# Plot mean and Std
ax.plot(T_K_array, Zbar_mean,'-' , color=colors[0])#, label=f'Initial guess')
ax.fill_between(T_K_array, Zbar_mean - Zbar_std, Zbar_mean + Zbar_std, color=colors[0], alpha=0.2)
ax2.plot(T_K_array, χ0_mean*AU_to_eV,'-' , color=colors[1])#, label=r'$\chi_0$')
ax2.fill_between(T_K_array, (χ0_mean - χ0_std)*AU_to_eV, (χ0_mean + χ0_std)*AU_to_eV, color=colors[1], alpha=0.2, linestyle='-')
           

# Plot all actual solution output    
colors = plt.cm.plasma(np.linspace(0, 1,len(Saha_list))) #plt.cycler("color", plt.cm.jet(np.linspace(0,1,len(Saha_list))))

for i, (Zbar_0, Saha) in enumerate(zip(Zbar_0_list, Saha_list)):
    if i==0:
        try:
            ax.plot(T_K_array, Saha[0],'^' , color=colors[i], label=f'Solution for colorbar initial guess', alpha=0.1, markersize=5)
            ax2.plot(T_K_array, Saha[1]*AU_to_eV,'^' , color=colors[i], label=r'$\chi_0$', alpha=0.1, markersize=5)
        except TypeError:
            pass
            
    else:
        try:
            ax.plot(T_K_array, Saha[0],'^' , color=colors[i],alpha=0.1, markersize=5)
            ax2.plot(T_K_array, Saha[1]*AU_to_eV,'^' , color=colors[i],alpha=0.1, markersize=5)
        except TypeError:
            pass


# Plot χ0 Line
ax2.plot(T_K_array, np.ones_like(T_K_array)*χ0_AU*AU_to_eV,'-' ,color='k')
ax2.text(np.min(T_K_array)*1.2, 1.01*χ0_AU*AU_to_eV, r"$\chi_0$ = {0:0.1f} [eV]".format(χ0_AU*AU_to_eV), fontsize=12,
        verticalalignment='bottom')#, bbox=props)

# Adding a manual colorbar
sm = plt.cm.ScalarMappable(cmap='plasma', norm=plt.Normalize(vmin=0, vmax=1))
sm.set_array([])
fig.colorbar(sm, ax=[ax, ax2], orientation='vertical', label=r'$\langle Z\rangle^{\rm initial guess}$')

plt.subplots_adjust(right=0.7)

# text
props = dict(boxstyle='round', facecolor='white', alpha=0.5)
inset_text = f"{element} at n = {n0_invcc:0.2e} [1/cc]"
ax.text(0.05, 0.95, inset_text, transform=ax.transAxes, fontsize=12,
        verticalalignment='top', bbox=props)

ax.set_ylim(1e-7,10)
ax2.set_ylim(1e-3,10*χ0_AU*AU_to_eV)

ax.set_yscale('log')
ax2.set_yscale('log')
ax.legend()
# plt.tight_layout()

# ax.set_yscale('log')

# %% [markdown]
# ## Argon

# %%
element='Ar'
g1 = 5.66 #6 
g0 = 1
χ0_eV = 15.8 # eV
χ0_AU = χ0_eV*eV_to_AU

n0_invcc = 2.53e21#6.3e26/1e6
n0_AU = n0_invcc*invcc_to_AU

# array
T_K_array = np.geomspace(2e2, 3e4, num=100)
Zbar_0_list = np.linspace(1e-6,1-1e-6, num=20)
Saha_list = [ solve_Saha(T_K_array*K_to_AU, n0_AU, Zbar_0=Zbar_0) for Zbar_0 in Zbar_0_list]
# Out:
# Considered failure.
# True: Te=0.024, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.929e-20]
#            x: [ 4.941e-324]
#         cost: 3.1437210268399195e-39
#          jac: [[ 2.369e-14]]
#         grad: [ 1.879e-33]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.025, n0=3.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 9.832e-19]
#            x: [ 4.941e-324]
#         cost: 4.833646280688322e-37
#          jac: [[ 2.723e-13]]
#         grad: [ 2.678e-31]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 6
#         njev: 6
# Considered failure.
# True: Te=0.027, n0=3.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.085e-17]
#            x: [ 4.941e-324]
#         cost: 5.88420706903282e-35
#          jac: [[ 2.785e-12]]
#         grad: [ 3.021e-29]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 6
#         njev: 6
# Considered failure.
# True: Te=0.028, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.071e-16]
#            x: [ 1.941e-27]
#         cost: 5.737048428610409e-33
#          jac: [[ 2.549e-11]]
#         grad: [ 2.730e-27]
#   optimality: 5.299951587361485e-54
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.030, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 9.518e-16]
#            x: [ 4.941e-324]
#         cost: 4.529338916852227e-31
#          jac: [[ 2.099e-10]]
#         grad: [ 1.997e-25]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.031, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.650e-15]
#            x: [ 1.336e-27]
#         cost: 2.925837955409773e-29
#          jac: [[ 1.563e-09]]
#         grad: [ 1.196e-23]
#   optimality: 1.59770046161318e-50
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.033, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.589e-14]
#            x: [ 4.941e-324]
#         cost: 1.5618345907969507e-27
#          jac: [[ 1.059e-08]]
#         grad: [ 5.916e-22]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.035, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.730e-13]
#            x: [ 4.941e-324]
#         cost: 6.954678605426431e-26
#          jac: [[ 6.547e-08]]
#         grad: [ 2.442e-20]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.036, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.283e-12]
#            x: [ 1.541e-33]
#         cost: 2.6065288929815644e-24
#          jac: [[ 3.714e-07]]
#         grad: [ 8.481e-19]
#   optimality: 1.3066862031110175e-51
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.038, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.288e-11]
#            x: [ 6.564e-28]
#         cost: 8.292507409936106e-23
#          jac: [[ 1.942e-06]]
#         grad: [ 2.501e-17]
#   optimality: 1.641385251369798e-44
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.040, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 6.720e-11]
#            x: [ 5.529e-28]
#         cost: 2.257662948113011e-21
#          jac: [[ 9.390e-06]]
#         grad: [ 6.310e-16]
#   optimality: 3.4888925946784113e-43
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.042, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.256e-10]
#            x: [ 4.941e-324]
#         cost: 5.300550668531056e-20
#          jac: [[ 4.217e-05]]
#         grad: [ 1.373e-14]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.044, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.470e-09]
#            x: [ 4.128e-28]
#         cost: 1.0810492529328594e-18
#          jac: [[ 1.765e-04]]
#         grad: [ 2.595e-13]
#   optimality: 1.0712857936677818e-40
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.047, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 6.211e-09]
#            x: [ 2.296e-28]
#         cost: 1.9286343237568325e-17
#          jac: [[ 6.910e-04]]
#         grad: [ 4.291e-12]
#   optimality: 9.854445460734955e-40
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.049, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.462e-08]
#            x: [ 4.941e-324]
#         cost: 3.029720899020122e-16
#          jac: [[ 2.538e-03]]
#         grad: [ 6.248e-11]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.052, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 9.184e-08]
#            x: [ 9.505e-29]
#         cost: 4.217261300532134e-15
#          jac: [[ 8.777e-03]]
#         grad: [ 8.061e-10]
#   optimality: 7.66193010413037e-38
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.054, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.235e-07]
#            x: [ 1.180e-28]
#         cost: 5.2326997304892254e-14
#          jac: [[ 2.866e-02]]
#         grad: [ 9.270e-09]
#   optimality: 1.0938525401760753e-36
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.057, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.079e-06]
#            x: [ 7.738e-29]
#         cost: 5.820400327179073e-13
#          jac: [[ 8.858e-02]]
#         grad: [ 9.557e-08]
#   optimality: 7.395062021189117e-36
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.060, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.416e-06]
#            x: [ 1.026e-29]
#         cost: 5.835181091333135e-12
#          jac: [[ 2.600e-01]]
#         grad: [ 8.881e-07]
#   optimality: 9.11069566974283e-36
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.063, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.030e-05]
#            x: [ 7.436e-29]
#         cost: 5.2997739088327016e-11
#          jac: [[ 7.261e-01]]
#         grad: [ 7.476e-06]
#   optimality: 5.558913745120899e-34
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.067, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.960e-05]
#            x: [ 2.602e-29]
#         cost: 4.382067242848469e-10
#          jac: [[ 1.935e+00]]
#         grad: [ 5.729e-05]
#   optimality: 1.490799083274377e-33
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.070, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 8.141e-05]
#            x: [ 1.204e-35]
#         cost: 3.3138443282949908e-09
#          jac: [[ 4.933e+00]]
#         grad: [ 4.016e-04]
#   optimality: 4.833670165441294e-39
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.074, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.146e-04]
#            x: [ 4.941e-324]
#         cost: 2.3021302298186572e-08
#          jac: [[ 1.205e+01]]
#         grad: [ 2.586e-03]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.078, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.432e-04]
#            x: [ 4.941e-324]
#         cost: 1.475337258290601e-07
#          jac: [[ 2.827e+01]]
#         grad: [ 1.536e-02]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.082, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.323e-03]
#            x: [ 4.941e-324]
#         cost: 8.756801807580282e-07
#          jac: [[ 6.385e+01]]
#         grad: [ 8.449e-02]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.086, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.109e-03]
#            x: [ 4.941e-324]
#         cost: 4.832104626800261e-06
#          jac: [[ 1.390e+02]]
#         grad: [ 4.321e-01]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.090, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.054e-03]
#            x: [ 1.299e-29]
#         cost: 2.4878627674141105e-05
#          jac: [[ 2.924e+02]]
#         grad: [ 2.062e+00]
#   optimality: 2.6794139636622656e-29
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.095, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.549e-02]
#            x: [ 4.941e-324]
#         cost: 0.00011992268828125592
#          jac: [[ 5.949e+02]]
#         grad: [ 9.214e+00]
#   optimality: 4.4e-323
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 8.523e-18]
#            x: [ 1.602e-01]
#         cost: 3.6320390828678297e-35
#          jac: [[ 1.623e-10]]
#         grad: [ 1.383e-27]
#   optimality: 2.21582563856643e-28
#  active_mask: [0]
#         nfev: 27
#         njev: 23
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 8.523e-18]
#            x: [ 1.602e-01]
#         cost: 3.6320390828678297e-35
#          jac: [[ 1.623e-10]]
#         grad: [ 1.383e-27]
#   optimality: 2.21582563856643e-28
#  active_mask: [0]
#         nfev: 27
#         njev: 23
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.946e-18]
#            x: [ 1.658e-01]
#         cost: 4.339831962221562e-36
#          jac: [[ 4.348e-09]]
#         grad: [ 1.281e-26]
#   optimality: 2.124296369965732e-27
#  active_mask: [0]
#         nfev: 26
#         njev: 25
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.437e-18]
#            x: [ 1.716e-01]
#         cost: 1.0329221486271813e-36
#          jac: [[ 2.021e-09]]
#         grad: [ 2.904e-27]
#   optimality: 4.984983643091151e-28
#  active_mask: [0]
#         nfev: 26
#         njev: 24
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.410e-18]
#            x: [ 1.776e-01]
#         cost: 1.463612381117064e-35
#          jac: [[ 1.188e-09]]
#         grad: [ 6.426e-27]
#   optimality: 1.1415716375588003e-27
#  active_mask: [0]
#         nfev: 27
#         njev: 24
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.502e-18]
#            x: [ 1.838e-01]
#         cost: 2.8143216480681836e-35
#          jac: [[ 6.488e-09]]
#         grad: [ 4.868e-26]
#   optimality: 8.948144131649456e-27
#  active_mask: [0]
#         nfev: 25
#         njev: 25
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.289e-18]
#            x: [ 1.902e-01]
#         cost: 1.398841759530906e-35
#          jac: [[ 6.519e-09]]
#         grad: [ 3.448e-26]
#   optimality: 6.5582265731666e-27
#  active_mask: [0]
#         nfev: 25
#         njev: 25
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.178e-15]
#            x: [ 5.227e-02]
#         cost: 5.0482811021621145e-30
#          jac: [[ 9.115e-06]]
#         grad: [ 2.896e-20]
#   optimality: 1.5137952600735426e-21
#  active_mask: [0]
#         nfev: 27
#         njev: 27
# Considered failure.
# True: Te=0.067, n0=3.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.960e-05]
#            x: [ 2.072e-27]
#         cost: 4.3820672428513027e-10
#          jac: [[ 1.935e+00]]
#         grad: [ 5.729e-05]
#   optimality: 1.1872656565492076e-31
#  active_mask: [-1]
#         nfev: 10
#         njev: 10
# Considered failure.
# True: Te=0.070, n0=3.7e-04, Zbar_0=0.053
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 8.141e-05]
#            x: [ 2.339e-32]
#         cost: 3.3138443282949908e-09
#          jac: [[ 4.933e+00]]
#         grad: [ 4.016e-04]
#   optimality: 9.39317345031629e-36
#  active_mask: [-1]
#         nfev: 11
#         njev: 11
# Considered failure.
# True: Te=0.074, n0=3.7e-04, Zbar_0=0.053
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 2.146e-04]
#            x: [ 1.871e-32]
#         cost: 2.3021302298186572e-08
#          jac: [[ 1.205e+01]]
#         grad: [ 2.586e-03]
#   optimality: 4.837165909751433e-35
#  active_mask: [-1]
#         nfev: 11
#         njev: 11
# Considered failure.
# True: Te=0.078, n0=3.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.432e-04]
#            x: [ 6.163e-33]
#         cost: 1.475337258290601e-07
#          jac: [[ 2.827e+01]]
#         grad: [ 1.536e-02]
#   optimality: 9.465344202778313e-35
#  active_mask: [-1]
#         nfev: 10
#         njev: 10
# Considered failure.
# True: Te=0.082, n0=3.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.323e-03]
#            x: [ 1.758e-28]
#         cost: 8.756801807581683e-07
#          jac: [[ 6.385e+01]]
#         grad: [ 8.449e-02]
#   optimality: 1.4852468073558501e-29
#  active_mask: [-1]
#         nfev: 10
#         njev: 10
# Considered failure.
# True: Te=0.086, n0=3.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.109e-03]
#            x: [ 2.133e-28]
#         cost: 4.832104626801035e-06
#          jac: [[ 1.390e+02]]
#         grad: [ 4.321e-01]
#   optimality: 9.217397730222431e-29
#  active_mask: [-1]
#         nfev: 10
#         njev: 10
# Considered failure.
# True: Te=0.090, n0=3.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.054e-03]
#            x: [ 5.368e-29]
#         cost: 2.4878627674142077e-05
#          jac: [[ 2.924e+02]]
#         grad: [ 2.062e+00]
#   optimality: 1.1070569679817015e-28
#  active_mask: [-1]
#         nfev: 10
#         njev: 10
# Considered failure.
# True: Te=0.095, n0=3.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.549e-02]
#            x: [ 4.941e-324]
#         cost: 0.00011992268828125592
#          jac: [[ 5.949e+02]]
#         grad: [ 9.214e+00]
#   optimality: 4.4e-323
#  active_mask: [-1]
#         nfev: 10
#         njev: 10
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 8.523e-18]
#            x: [ 1.602e-01]
#         cost: 3.6323214142579867e-35
#          jac: [[ 1.622e-10]]
#         grad: [ 1.383e-27]
#   optimality: 2.215264328925604e-28
#  active_mask: [0]
#         nfev: 26
#         njev: 22
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 8.523e-18]
#            x: [ 1.602e-01]
#         cost: 3.6323214142579867e-35
#          jac: [[ 1.622e-10]]
#         grad: [ 1.383e-27]
#   optimality: 2.215264328925604e-28
#  active_mask: [0]
#         nfev: 26
#         njev: 22
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.944e-18]
#            x: [ 1.658e-01]
#         cost: 4.334486772694417e-36
#          jac: [[ 4.348e-09]]
#         grad: [ 1.280e-26]
#   optimality: 2.1227620454958186e-27
#  active_mask: [0]
#         nfev: 25
#         njev: 24
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.438e-18]
#            x: [ 1.716e-01]
#         cost: 1.0332584615420526e-36
#          jac: [[ 2.020e-09]]
#         grad: [ 2.905e-27]
#   optimality: 4.98557487208487e-28
#  active_mask: [0]
#         nfev: 25
#         njev: 23
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.410e-18]
#            x: [ 1.776e-01]
#         cost: 1.4636673434494497e-35
#          jac: [[ 1.188e-09]]
#         grad: [ 6.426e-27]
#   optimality: 1.1415729776077966e-27
#  active_mask: [0]
#         nfev: 26
#         njev: 23
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.503e-18]
#            x: [ 1.838e-01]
#         cost: 2.814387012491491e-35
#          jac: [[ 6.488e-09]]
#         grad: [ 4.868e-26]
#   optimality: 8.948270016338505e-27
#  active_mask: [0]
#         nfev: 24
#         njev: 24
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.290e-18]
#            x: [ 1.902e-01]
#         cost: 1.3989547023042837e-35
#          jac: [[ 6.519e-09]]
#         grad: [ 3.448e-26]
#   optimality: 6.558540346991903e-27
#  active_mask: [0]
#         nfev: 24
#         njev: 24
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.105e-18]
#            x: [ 1.967e-01]
#         cost: 8.425988472839352e-36
#          jac: [[ 6.734e-09]]
#         grad: [ 2.764e-26]
#   optimality: 5.4384509435556095e-27
#  active_mask: [0]
#         nfev: 24
#         njev: 24
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.523e-18]
#            x: [ 2.035e-01]
#         cost: 6.204994542360878e-36
#          jac: [[ 7.111e-09]]
#         grad: [ 2.505e-26]
#   optimality: 5.0978975234642134e-27
#  active_mask: [0]
#         nfev: 24
#         njev: 24
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.410e-18]
#            x: [ 2.104e-01]
#         cost: 5.8146901490361693e-36
#          jac: [[ 7.670e-09]]
#         grad: [ 2.615e-26]
#   optimality: 5.504107689249447e-27
#  active_mask: [0]
#         nfev: 24
#         njev: 24
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.805e-18]
#            x: [ 2.176e-01]
#         cost: 7.23963784463166e-36
#          jac: [[ 8.453e-09]]
#         grad: [ 3.217e-26]
#   optimality: 6.999218832346431e-27
#  active_mask: [0]
#         nfev: 24
#         njev: 24
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.950e-18]
#            x: [ 2.249e-01]
#         cost: 1.2253723403217946e-35
#          jac: [[ 9.542e-09]]
#         grad: [ 4.724e-26]
#   optimality: 1.0626114126894043e-26
#  active_mask: [0]
#         nfev: 24
#         njev: 24
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.508e-18]
#            x: [ 2.325e-01]
#         cost: 2.8182570341184074e-35
#          jac: [[ 1.108e-08]]
#         grad: [ 8.316e-26]
#   optimality: 1.9335239972805403e-26
#  active_mask: [0]
#         nfev: 24
#         njev: 24
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.166e-19]
#            x: [ 2.403e-01]
#         cost: 8.677213970345917e-38
#          jac: [[ 7.051e-09]]
#         grad: [ 2.938e-27]
#   optimality: 7.058284131311369e-28
#  active_mask: [0]
#         nfev: 24
#         njev: 23
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.487e-17]
#            x: [ 2.483e-01]
#         cost: 1.1060323050473885e-34
#          jac: [[ 2.889e-09]]
#         grad: [ 4.297e-26]
#   optimality: 1.066818486656875e-26
#  active_mask: [0]
#         nfev: 25
#         njev: 23
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.866e-18]
#            x: [ 2.565e-01]
#         cost: 1.720287267219089e-35
#          jac: [[ 1.367e-08]]
#         grad: [ 8.015e-26]
#   optimality: 2.0556342362666932e-26
#  active_mask: [0]
#         nfev: 26
#         njev: 25
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.720e-17]
#            x: [ 2.649e-01]
#         cost: 1.4796774396805921e-34
#          jac: [[ 1.783e-08]]
#         grad: [ 3.067e-25]
#   optimality: 8.124739643146278e-26
#  active_mask: [0]
#         nfev: 25
#         njev: 25
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.964e-18]
#            x: [ 2.735e-01]
#         cost: 1.9277105340902967e-36
#          jac: [[ 1.443e-08]]
#         grad: [ 2.834e-26]
#   optimality: 7.75113057651166e-27
#  active_mask: [0]
#         nfev: 25
#         njev: 25
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.378e-19]
#            x: [ 2.823e-01]
#         cost: 9.581455595052364e-38
#          jac: [[ 1.197e-08]]
#         grad: [ 5.238e-27]
#   optimality: 1.4790114871953178e-27
#  active_mask: [0]
#         nfev: 25
#         njev: 24
# Considered failure.
# True: Te=0.002, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.826e-18]
#            x: [ 2.914e-01]
#         cost: 1.6971325524365582e-35
#          jac: [[ 9.866e-09]]
#         grad: [ 5.748e-26]
#   optimality: 1.674962797733589e-26
#  active_mask: [0]
#         nfev: 25
#         njev: 24
# Considered failure.
# True: Te=0.002, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.591e-17]
#            x: [ 3.007e-01]
#         cost: 1.2663098723310517e-34
#          jac: [[ 7.932e-09]]
#         grad: [ 1.262e-25]
#   optimality: 3.7956101491860786e-26
#  active_mask: [0]
#         nfev: 25
#         njev: 24
# Considered failure.
# True: Te=0.002, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.012e-17]
#            x: [ 3.102e-01]
#         cost: 4.536864849680379e-34
#          jac: [[ 5.991e-09]]
#         grad: [ 1.805e-25]
#   optimality: 5.597873924915114e-26
#  active_mask: [0]
#         nfev: 26
#         njev: 24
# Considered failure.
# True: Te=0.002, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.836e-17]
#            x: [ 3.199e-01]
#         cost: 1.1693722440535691e-33
#          jac: [[ 3.961e-09]]
#         grad: [ 1.916e-25]
#   optimality: 6.128623634029916e-26
#  active_mask: [0]
#         nfev: 26
#         njev: 24
# Considered failure.
# True: Te=0.002, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.066e-17]
#            x: [ 3.299e-01]
#         cost: 2.496349379443258e-33
#          jac: [[ 1.801e-09]]
#         grad: [ 1.272e-25]
#   optimality: 4.197469962345779e-26
#  active_mask: [0]
#         nfev: 27
#         njev: 24
# Considered failure.
# True: Te=0.002, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.491e-16]
#            x: [ 1.055e-01]
#         cost: 1.0082441597773456e-31
#          jac: [[ 5.831e-06]]
#         grad: [ 2.619e-21]
#   optimality: 2.7621537159667554e-22
#  active_mask: [0]
#         nfev: 17
#         njev: 15
# Considered failure.
# True: Te=0.070, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 8.141e-05]
#            x: [ 2.869e-28]
#         cost: 3.313844328295814e-09
#          jac: [[ 4.933e+00]]
#         grad: [ 4.016e-04]
#   optimality: 1.1519724545184743e-31
#  active_mask: [-1]
#         nfev: 11
#         njev: 11
# Considered failure.
# True: Te=0.074, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.146e-04]
#            x: [ 6.126e-28]
#         cost: 2.3021302298194348e-08
#          jac: [[ 1.205e+01]]
#         grad: [ 2.586e-03]
#   optimality: 1.5840611690801675e-30
#  active_mask: [-1]
#         nfev: 11
#         njev: 11
# Considered failure.
# True: Te=0.078, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.432e-04]
#            x: [ 4.941e-324]
#         cost: 1.475337258290601e-07
#          jac: [[ 2.827e+01]]
#         grad: [ 1.536e-02]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 11
#         njev: 11
# Considered failure.
# True: Te=0.082, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.323e-03]
#            x: [ 4.941e-324]
#         cost: 8.756801807580282e-07
#          jac: [[ 6.385e+01]]
#         grad: [ 8.449e-02]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 11
#         njev: 11
# Considered failure.
# True: Te=0.086, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.109e-03]
#            x: [ 1.548e-28]
#         cost: 4.832104626800915e-06
#          jac: [[ 1.390e+02]]
#         grad: [ 4.321e-01]
#   optimality: 6.688525090521896e-29
#  active_mask: [-1]
#         nfev: 11
#         njev: 11
# Considered failure.
# True: Te=0.090, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.054e-03]
#            x: [ 4.941e-324]
#         cost: 2.4878627674140305e-05
#          jac: [[ 2.924e+02]]
#         grad: [ 2.062e+00]
#   optimality: 1e-323
#  active_mask: [-1]
#         nfev: 11
#         njev: 11
# Considered failure.
# True: Te=0.095, n0=3.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.549e-02]
#            x: [ 4.941e-324]
#         cost: 0.00011992268828125592
#          jac: [[ 5.949e+02]]
#         grad: [ 9.214e+00]
#   optimality: 4.4e-323
#  active_mask: [-1]
#         nfev: 11
#         njev: 11
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.485e-18]
#            x: [ 1.602e-01]
#         cost: 6.071682409507301e-36
#          jac: [[ 4.163e-09]]
#         grad: [ 1.451e-26]
#   optimality: 2.3237110477212293e-27
#  active_mask: [0]
#         nfev: 21
#         njev: 20
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.485e-18]
#            x: [ 1.602e-01]
#         cost: 6.071682409507301e-36
#          jac: [[ 4.163e-09]]
#         grad: [ 1.451e-26]
#   optimality: 2.3237110477212293e-27
#  active_mask: [0]
#         nfev: 21
#         njev: 20
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.585e-18]
#            x: [ 1.658e-01]
#         cost: 6.42434322626113e-36
#          jac: [[ 1.192e-09]]
#         grad: [ 4.273e-27]
#   optimality: 7.0865441590141895e-28
#  active_mask: [0]
#         nfev: 22
#         njev: 20
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.707e-20]
#            x: [ 1.716e-01]
#         cost: 1.107950338514172e-39
#          jac: [[ 2.919e-09]]
#         grad: [ 1.374e-28]
#   optimality: 2.3584040799428903e-29
#  active_mask: [0]
#         nfev: 22
#         njev: 21
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.167e-17]
#            x: [ 1.776e-01]
#         cost: 6.810120333551762e-35
#          jac: [[ 1.440e-10]]
#         grad: [ 1.680e-27]
#   optimality: 2.9850694527728774e-28
#  active_mask: [0]
#         nfev: 25
#         njev: 21
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.304e-18]
#            x: [ 1.838e-01]
#         cost: 2.6533351271667003e-36
#          jac: [[ 5.264e-09]]
#         grad: [ 1.213e-26]
#   optimality: 2.2291485075986427e-27
#  active_mask: [0]
#         nfev: 23
#         njev: 23
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 6.280e-19]
#            x: [ 1.902e-01]
#         cost: 1.9720344479517824e-37
#          jac: [[ 3.273e-09]]
#         grad: [ 2.056e-27]
#   optimality: 3.909560706291799e-28
#  active_mask: [0]
#         nfev: 23
#         njev: 22
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 6.168e-18]
#            x: [ 1.967e-01]
#         cost: 1.9025076362493175e-35
#          jac: [[ 1.774e-09]]
#         grad: [ 1.094e-26]
#   optimality: 2.1530263769060664e-27
#  active_mask: [0]
#         nfev: 24
#         njev: 22
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.588e-17]
#            x: [ 2.035e-01]
#         cost: 1.260565806778273e-34
#          jac: [[ 3.557e-10]]
#         grad: [ 5.648e-27]
#   optimality: 1.1494410643147052e-27
#  active_mask: [0]
#         nfev: 26
#         njev: 22
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.237e-18]
#            x: [ 2.104e-01]
#         cost: 2.502534723211647e-36
#          jac: [[ 3.631e-09]]
#         grad: [ 8.124e-27]
#   optimality: 1.709564174805097e-27
#  active_mask: [0]
#         nfev: 25
#         njev: 23
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 9.665e-18]
#            x: [ 2.176e-01]
#         cost: 4.6706548153280483e-35
#          jac: [[ 9.921e-09]]
#         grad: [ 9.589e-26]
#   optimality: 2.0864313091257677e-26
#  active_mask: [0]
#         nfev: 24
#         njev: 24
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.634e-18]
#            x: [ 2.249e-01]
#         cost: 3.467752320685113e-36
#          jac: [[ 8.741e-09]]
#         grad: [ 2.302e-26]
#   optimality: 5.178569463647134e-27
#  active_mask: [0]
#         nfev: 24
#         njev: 24
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.770e-19]
#            x: [ 2.325e-01]
#         cost: 3.837401555836794e-38
#          jac: [[ 7.988e-09]]
#         grad: [ 2.213e-27]
#   optimality: 5.1450976409414295e-28
#  active_mask: [0]
#         nfev: 24
#         njev: 24
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.220e-19]
#            x: [ 2.403e-01]
#         cost: 2.4645483463549644e-38
#          jac: [[ 7.307e-09]]
#         grad: [ 1.622e-27]
#   optimality: 3.897838170131182e-28
#  active_mask: [0]
#         nfev: 24
#         njev: 23
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.819e-18]
#            x: [ 2.483e-01]
#         cost: 1.654336439843638e-36
#          jac: [[ 6.749e-09]]
#         grad: [ 1.228e-26]
#   optimality: 3.0478053046428134e-27
#  active_mask: [0]
#         nfev: 24
#         njev: 23
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.585e-18]
#            x: [ 2.565e-01]
#         cost: 1.0511280291777678e-35
#          jac: [[ 6.284e-09]]
#         grad: [ 2.881e-26]
#   optimality: 7.38895465519894e-27
#  active_mask: [0]
#         nfev: 24
#         njev: 23
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 8.266e-18]
#            x: [ 2.649e-01]
#         cost: 3.4161299445888673e-35
#          jac: [[ 5.887e-09]]
#         grad: [ 4.866e-26]
#   optimality: 1.2888161448101062e-26
#  active_mask: [0]
#         nfev: 24
#         njev: 23
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.267e-17]
#            x: [ 2.735e-01]
#         cost: 8.027357487872879e-35
#          jac: [[ 5.557e-09]]
#         grad: [ 7.042e-26]
#   optimality: 1.9258523822208973e-26
#  active_mask: [0]
#         nfev: 24
#         njev: 23
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.760e-17]
#            x: [ 2.823e-01]
#         cost: 1.5489444889648685e-34
#          jac: [[ 5.311e-09]]
#         grad: [ 9.349e-26]
#   optimality: 2.639534687129981e-26
#  active_mask: [0]
#         nfev: 25
#         njev: 23
# Considered failure.
# True: Te=0.002, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.281e-17]
#            x: [ 2.914e-01]
#         cost: 2.6019452300631566e-34
#          jac: [[ 5.180e-09]]
#         grad: [ 1.182e-25]
#   optimality: 3.443690040188597e-26
#  active_mask: [0]
#         nfev: 25
#         njev: 23
# Considered failure.
# True: Te=0.002, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.799e-17]
#            x: [ 3.007e-01]
#         cost: 3.918199860935799e-34
#          jac: [[ 5.212e-09]]
#         grad: [ 1.459e-25]
#   optimality: 4.386977585062942e-26
#  active_mask: [0]
#         nfev: 25
#         njev: 23
# Considered failure.
# True: Te=0.002, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.275e-17]
#            x: [ 3.102e-01]
#         cost: 5.364208631308869e-34
#          jac: [[ 5.474e-09]]
#         grad: [ 1.793e-25]
#   optimality: 5.561488634465923e-26
#  active_mask: [0]
#         nfev: 25
#         njev: 23
# Considered failure.
# True: Te=0.002, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.662e-17]
#            x: [ 3.199e-01]
#         cost: 6.704177971668291e-34
#          jac: [[ 6.060e-09]]
#         grad: [ 2.219e-25]
#   optimality: 7.098949640650043e-26
#  active_mask: [0]
#         nfev: 25
#         njev: 23
# Considered failure.
# True: Te=0.002, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.903e-17]
#            x: [ 3.299e-01]
#         cost: 7.615818225952564e-34
#          jac: [[ 7.097e-09]]
#         grad: [ 2.770e-25]
#   optimality: 9.136667992313208e-26
#  active_mask: [0]
#         nfev: 25
#         njev: 23
# Considered failure.
# True: Te=0.002, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.938e-17]
#            x: [ 3.400e-01]
#         cost: 7.75304191402511e-34
#          jac: [[ 8.758e-09]]
#         grad: [ 3.449e-25]
#   optimality: 1.1725704172945086e-25
#  active_mask: [0]
#         nfev: 25
#         njev: 23
# Considered failure.
# True: Te=0.002, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.707e-17]
#            x: [ 3.504e-01]
#         cost: 6.870214891047912e-34
#          jac: [[ 1.128e-08]]
#         grad: [ 4.180e-25]
#   optimality: 1.4646125526317206e-25
#  active_mask: [0]
#         nfev: 24
#         njev: 23
# Considered failure.
# True: Te=0.002, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.255e-17]
#            x: [ 3.610e-01]
#         cost: 7.874014638749476e-35
#          jac: [[ 2.101e-08]]
#         grad: [ 2.637e-25]
#   optimality: 9.518401286921103e-26
#  active_mask: [0]
#         nfev: 26
#         njev: 24
# Considered failure.
# True: Te=0.002, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.082e-17]
#            x: [ 3.718e-01]
#         cost: 5.848440936089064e-35
#          jac: [[ 4.513e-08]]
#         grad: [ 4.881e-25]
#   optimality: 1.814643952509256e-25
#  active_mask: [0]
#         nfev: 25
#         njev: 25
# Considered failure.
# True: Te=0.002, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.389e-18]
#            x: [ 3.827e-01]
#         cost: 9.633815788153745e-36
#          jac: [[ 3.252e-08]]
#         grad: [ 1.428e-25]
#   optimality: 5.46402993381562e-26
#  active_mask: [0]
#         nfev: 25
#         njev: 24
# Considered failure.
# True: Te=0.003, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.041e-17]
#            x: [ 3.939e-01]
#         cost: 8.163147928574525e-34
#          jac: [[ 2.231e-08]]
#         grad: [ 9.015e-25]
#   optimality: 3.5512583052588094e-25
#  active_mask: [0]
#         nfev: 25
#         njev: 24
# Considered failure.
# True: Te=0.003, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.042e-16]
#            x: [ 4.053e-01]
#         cost: 5.427606622306831e-33
#          jac: [[ 1.246e-08]]
#         grad: [ 1.299e-24]
#   optimality: 5.263048250521771e-25
#  active_mask: [0]
#         nfev: 26
#         njev: 24
# Considered failure.
# True: Te=0.003, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.948e-16]
#            x: [ 4.169e-01]
#         cost: 1.897138504804651e-32
#          jac: [[ 1.958e-09]]
#         grad: [ 3.813e-25]
#   optimality: 1.5896958284815252e-25
#  active_mask: [0]
#         nfev: 28
#         njev: 24
# Considered failure.
# True: Te=0.003, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.077e-18]
#            x: [ 4.286e-01]
#         cost: 5.797447116177356e-37
#          jac: [[ 5.914e-08]]
#         grad: [ 6.368e-26]
#   optimality: 2.7296455714346687e-26
#  active_mask: [0]
#         nfev: 27
#         njev: 25
# Considered failure.
# True: Te=0.003, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.085e-16]
#            x: [ 4.405e-01]
#         cost: 5.883384419653439e-33
#          jac: [[ 2.607e-08]]
#         grad: [ 2.828e-24]
#   optimality: 1.2457999435992919e-24
#  active_mask: [0]
#         nfev: 27
#         njev: 25
# Considered failure.
# True: Te=0.003, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.281e-16]
#            x: [ 4.526e-01]
#         cost: 8.206755578015229e-33
#          jac: [[ 1.343e-07]]
#         grad: [ 1.721e-23]
#   optimality: 7.789660233894921e-24
#  active_mask: [0]
#         nfev: 26
#         njev: 26
# Considered failure.
# True: Te=0.004, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.524e-15]
#            x: [ 1.580e-01]
#         cost: 6.210723879996294e-30
#          jac: [[ 9.013e-06]]
#         grad: [ 3.177e-20]
#   optimality: 5.018746031732895e-21
#  active_mask: [0]
#         nfev: 15
#         njev: 15
# Considered failure.
# True: Te=0.004, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 9.577e-15]
#            x: [ 1.635e-01]
#         cost: 4.585480490873119e-29
#          jac: [[ 1.058e-05]]
#         grad: [ 1.013e-19]
#   optimality: 1.6574531414838358e-20
#  active_mask: [0]
#         nfev: 22
#         njev: 18
# Considered failure.
# True: Te=0.070, n0=3.7e-04, Zbar_0=0.158
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 8.141e-05]
#            x: [ 1.200e-31]
#         cost: 3.313844328295014e-09
#          jac: [[ 4.933e+00]]
#         grad: [ 4.016e-04]
#   optimality: 4.820607261414024e-35
#  active_mask: [-1]
#         nfev: 12
#         njev: 12
# Considered failure.
# True: Te=0.074, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.146e-04]
#            x: [ 4.941e-324]
#         cost: 2.3021302298186572e-08
#          jac: [[ 1.205e+01]]
#         grad: [ 2.586e-03]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 12
#         njev: 12
# Considered failure.
# True: Te=0.078, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.432e-04]
#            x: [ 1.069e-31]
#         cost: 1.4753372582906059e-07
#          jac: [[ 2.827e+01]]
#         grad: [ 1.536e-02]
#   optimality: 1.6416456351659866e-33
#  active_mask: [-1]
#         nfev: 12
#         njev: 12
# Considered failure.
# True: Te=0.082, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.323e-03]
#            x: [ 1.839e-28]
#         cost: 8.756801807581683e-07
#          jac: [[ 6.385e+01]]
#         grad: [ 8.449e-02]
#   optimality: 1.5537073108489697e-29
#  active_mask: [-1]
#         nfev: 12
#         njev: 12
# Considered failure.
# True: Te=0.086, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.109e-03]
#            x: [ 4.941e-324]
#         cost: 4.832104626800261e-06
#          jac: [[ 1.390e+02]]
#         grad: [ 4.321e-01]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 12
#         njev: 12
# Considered failure.
# True: Te=0.090, n0=3.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.054e-03]
#            x: [ 4.941e-324]
#         cost: 2.4878627674140305e-05
#          jac: [[ 2.924e+02]]
#         grad: [ 2.062e+00]
#   optimality: 1e-323
#  active_mask: [-1]
#         nfev: 12
#         njev: 12
# Considered failure.
# True: Te=0.095, n0=3.7e-04, Zbar_0=0.158
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.549e-02]
#            x: [ 2.155e-31]
#         cost: 0.00011992268828125628
#          jac: [[ 5.949e+02]]
#         grad: [ 9.214e+00]
#   optimality: 1.985399353033704e-30
#  active_mask: [-1]
#         nfev: 12
#         njev: 12
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.211
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.650e-18]
#            x: [ 1.602e-01]
#         cost: 6.66110351185962e-36
#          jac: [[ 4.199e-09]]
#         grad: [ 1.533e-26]
#   optimality: 2.4552657115333114e-27
#  active_mask: [0]
#         nfev: 28
#         njev: 28
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.211
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.650e-18]
#            x: [ 1.602e-01]
#         cost: 6.66110351185962e-36
#          jac: [[ 4.199e-09]]
#         grad: [ 1.533e-26]
#   optimality: 2.4552657115333114e-27
#  active_mask: [0]
#         nfev: 28
#         njev: 28
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.211
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.529e-18]
#            x: [ 1.658e-01]
#         cost: 6.227772894792805e-36
#          jac: [[ 4.490e-09]]
#         grad: [ 1.585e-26]
#   optimality: 2.6277437300949965e-27
#  active_mask: [0]
#         nfev: 28
#         njev: 28
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.211
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.321e-18]
#            x: [ 1.716e-01]
#         cost: 1.4155438560047833e-35
#          jac: [[ 5.227e-09]]
#         grad: [ 2.781e-26]
#   optimality: 4.774156921344946e-27
#  active_mask: [0]
#         nfev: 27
#         njev: 27
# Considered failure.
# True: Te=0.001, n0=3.7e-04, Zbar_0=0.211
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
# ...
#   optimality: 2.0816920308055384e-19
#  active_mask: [0]
#         nfev: 58
#         njev: 58
# Considered failure.
# True: Te=0.013, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 6.129e-14]
#            x: [ 7.763e-01]
#         cost: 1.878110350628708e-27
#          jac: [[ 1.477e-05]]
#         grad: [ 9.053e-19]
#   optimality: 7.027828616432797e-19
#  active_mask: [0]
#         nfev: 57
#         njev: 57
# Considered failure.
# True: Te=0.013, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 6.305e-14]
#            x: [ 7.869e-01]
#         cost: 1.9873850856207647e-27
#          jac: [[ 1.715e-05]]
#         grad: [ 1.081e-18]
#   optimality: 8.509225671765891e-19
#  active_mask: [0]
#         nfev: 57
#         njev: 57
# Considered failure.
# True: Te=0.014, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 6.538e-14]
#            x: [ 7.973e-01]
#         cost: 2.1374295741447435e-27
#          jac: [[ 2.005e-05]]
#         grad: [ 1.311e-18]
#   optimality: 1.0451632423567495e-18
#  active_mask: [0]
#         nfev: 57
#         njev: 57
# Considered failure.
# True: Te=0.015, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 6.836e-14]
#            x: [ 8.073e-01]
#         cost: 2.3368327770166213e-27
#          jac: [[ 2.359e-05]]
#         grad: [ 1.613e-18]
#   optimality: 1.3022853365072548e-18
#  active_mask: [0]
#         nfev: 57
#         njev: 57
# Considered failure.
# True: Te=0.015, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.207e-14]
#            x: [ 8.171e-01]
#         cost: 2.5973182528704936e-27
#          jac: [[ 2.795e-05]]
#         grad: [ 2.014e-18]
#   optimality: 1.6459847642772363e-18
#  active_mask: [0]
#         nfev: 57
#         njev: 57
# Considered failure.
# True: Te=0.016, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.625e-13]
#            x: [ 8.265e-01]
#         cost: 1.320104953265004e-26
#          jac: [[ 4.146e-05]]
#         grad: [ 6.737e-18]
#   optimality: 5.5684675969356515e-18
#  active_mask: [0]
#         nfev: 56
#         njev: 56
# Considered failure.
# True: Te=0.017, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.687e-13]
#            x: [ 8.356e-01]
#         cost: 1.4236206919020332e-26
#          jac: [[ 4.892e-05]]
#         grad: [ 8.255e-18]
#   optimality: 6.89837262737158e-18
#  active_mask: [0]
#         nfev: 56
#         njev: 56
# Considered failure.
# True: Te=0.018, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.768e-13]
#            x: [ 8.444e-01]
#         cost: 1.562966551223985e-26
#          jac: [[ 5.814e-05]]
#         grad: [ 1.028e-17]
#   optimality: 8.679609358470299e-18
#  active_mask: [0]
#         nfev: 56
#         njev: 56
# Considered failure.
# True: Te=0.019, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.869e-13]
#            x: [ 8.529e-01]
#         cost: 1.7469953350695995e-26
#          jac: [[ 6.956e-05]]
#         grad: [ 1.300e-17]
#   optimality: 1.1090054191189526e-17
#  active_mask: [0]
#         nfev: 56
#         njev: 56
# Considered failure.
# True: Te=0.020, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.270e-13]
#            x: [ 8.610e-01]
#         cost: 9.115491029753736e-26
#          jac: [[ 1.048e-04]]
#         grad: [ 4.475e-17]
#   optimality: 3.853310733209403e-17
#  active_mask: [0]
#         nfev: 55
#         njev: 55
# Considered failure.
# True: Te=0.021, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.444e-13]
#            x: [ 8.689e-01]
#         cost: 9.875323191090644e-26
#          jac: [[ 1.248e-04]]
#         grad: [ 5.548e-17]
#   optimality: 4.820497715131358e-17
#  active_mask: [0]
#         nfev: 55
#         njev: 55
# Considered failure.
# True: Te=0.022, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.670e-13]
#            x: [ 8.763e-01]
#         cost: 1.090673187468876e-25
#          jac: [[ 1.498e-04]]
#         grad: [ 6.996e-17]
#   optimality: 6.13113195656307e-17
#  active_mask: [0]
#         nfev: 55
#         njev: 55
# Considered failure.
# True: Te=0.023, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.104e-12]
#            x: [ 8.835e-01]
#         cost: 6.091963303675433e-25
#          jac: [[ 2.314e-04]]
#         grad: [ 2.554e-16]
#   optimality: 2.2568359426808666e-16
#  active_mask: [0]
#         nfev: 54
#         njev: 54
# Considered failure.
# True: Te=0.024, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.141e-12]
#            x: [ 8.903e-01]
#         cost: 6.508274285729885e-25
#          jac: [[ 2.761e-04]]
#         grad: [ 3.150e-16]
#   optimality: 2.80429238385862e-16
#  active_mask: [0]
#         nfev: 54
#         njev: 54
# Considered failure.
# True: Te=0.025, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.191e-12]
#            x: [ 8.969e-01]
#         cost: 7.096882494535177e-25
#          jac: [[ 3.319e-04]]
#         grad: [ 3.954e-16]
#   optimality: 3.5464921892288227e-16
#  active_mask: [0]
#         nfev: 54
#         njev: 54
# Considered failure.
# True: Te=0.027, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.257e-12]
#            x: [ 9.031e-01]
#         cost: 7.8991319072747935e-25
#          jac: [[ 4.021e-04]]
#         grad: [ 5.054e-16]
#   optimality: 4.563841441060513e-16
#  active_mask: [0]
#         nfev: 54
#         njev: 54
# Considered failure.
# True: Te=0.028, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.982e-12]
#            x: [ 9.090e-01]
#         cost: 4.445162219500493e-24
#          jac: [[ 6.269e-04]]
#         grad: [ 1.869e-15]
#   optimality: 1.6990501318797937e-15
#  active_mask: [0]
#         nfev: 53
#         njev: 53
# Considered failure.
# True: Te=0.030, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.093e-12]
#            x: [ 9.146e-01]
#         cost: 4.783518734349236e-24
#          jac: [[ 7.546e-04]]
#         grad: [ 2.334e-15]
#   optimality: 2.1345631121552993e-15
#  active_mask: [0]
#         nfev: 53
#         njev: 53
# Considered failure.
# True: Te=0.031, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.244e-12]
#            x: [ 9.199e-01]
#         cost: 5.260214363616144e-24
#          jac: [[ 9.154e-04]]
#         grad: [ 2.969e-15]
#   optimality: 2.7314115765139306e-15
#  active_mask: [0]
#         nfev: 53
#         njev: 53
# Considered failure.
# True: Te=0.033, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.438e-12]
#            x: [ 9.249e-01]
#         cost: 5.910454762345389e-24
#          jac: [[ 1.119e-03]]
#         grad: [ 3.847e-15]
#   optimality: 3.55869623983289e-15
#  active_mask: [0]
#         nfev: 53
#         njev: 53
# Considered failure.
# True: Te=0.035, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 8.150e-12]
#            x: [ 9.297e-01]
#         cost: 3.320933398540274e-23
#          jac: [[ 1.755e-03]]
#         grad: [ 1.430e-14]
#   optimality: 1.3295780183754424e-14
#  active_mask: [0]
#         nfev: 52
#         njev: 52
# Considered failure.
# True: Te=0.036, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 8.493e-12]
#            x: [ 9.342e-01]
#         cost: 3.6066997509093964e-23
#          jac: [[ 2.130e-03]]
#         grad: [ 1.809e-14]
#   optimality: 1.6903312557691887e-14
#  active_mask: [0]
#         nfev: 52
#         njev: 52
# Considered failure.
# True: Te=0.038, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 8.952e-12]
#            x: [ 9.385e-01]
#         cost: 4.0065362817839953e-23
#          jac: [[ 2.607e-03]]
#         grad: [ 2.334e-14]
#   optimality: 2.189950212781384e-14
#  active_mask: [0]
#         nfev: 52
#         njev: 52
# Considered failure.
# True: Te=0.040, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 9.541e-12]
#            x: [ 9.425e-01]
#         cost: 4.551331676770699e-23
#          jac: [[ 3.214e-03]]
#         grad: [ 3.066e-14]
#   optimality: 2.8899621804436485e-14
#  active_mask: [0]
#         nfev: 52
#         njev: 52
# Considered failure.
# True: Te=0.042, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.251e-11]
#            x: [ 9.463e-01]
#         cost: 2.533942178249723e-22
#          jac: [[ 5.053e-03]]
#         grad: [ 1.137e-13]
#   optimality: 1.0763612995741344e-13
#  active_mask: [0]
#         nfev: 51
#         njev: 51
# Considered failure.
# True: Te=0.044, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.359e-11]
#            x: [ 9.498e-01]
#         cost: 2.7821044879975596e-22
#          jac: [[ 6.184e-03]]
#         grad: [ 1.459e-13]
#   optimality: 1.3856130716294972e-13
#  active_mask: [0]
#         nfev: 51
#         njev: 51
# Considered failure.
# True: Te=0.047, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.501e-11]
#            x: [ 9.532e-01]
#         cost: 3.1265798843140175e-22
#          jac: [[ 7.629e-03]]
#         grad: [ 1.908e-13]
#   optimality: 1.8182903311391009e-13
#  active_mask: [0]
#         nfev: 51
#         njev: 51
# Considered failure.
# True: Te=0.049, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 6.028e-11]
#            x: [ 9.563e-01]
#         cost: 1.8165624196754627e-21
#          jac: [[ 1.218e-02]]
#         grad: [ 7.342e-13]
#   optimality: 7.021473833659735e-13
#  active_mask: [0]
#         nfev: 50
#         njev: 50
# Considered failure.
# True: Te=0.052, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 6.279e-11]
#            x: [ 9.592e-01]
#         cost: 1.9710424879089347e-21
#          jac: [[ 1.490e-02]]
#         grad: [ 9.357e-13]
#   optimality: 8.975706928483503e-13
#  active_mask: [0]
#         nfev: 50
#         njev: 50
# Considered failure.
# True: Te=0.054, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 6.619e-11]
#            x: [ 9.620e-01]
#         cost: 2.19080981265922e-21
#          jac: [[ 1.838e-02]]
#         grad: [ 1.217e-12]
#   optimality: 1.1704264100869714e-12
#  active_mask: [0]
#         nfev: 50
#         njev: 50
# Considered failure.
# True: Te=0.057, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.062e-11]
#            x: [ 9.646e-01]
#         cost: 2.4936403411854304e-21
#          jac: [[ 2.284e-02]]
#         grad: [ 1.613e-12]
#   optimality: 1.5559543695610003e-12
#  active_mask: [0]
#         nfev: 50
#         njev: 50
# Considered failure.
# True: Te=0.060, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.685e-10]
#            x: [ 9.670e-01]
#         cost: 1.4199476654485955e-20
#          jac: [[ 3.639e-02]]
#         grad: [ 6.133e-12]
#   optimality: 5.930616023778679e-12
#  active_mask: [0]
#         nfev: 49
#         njev: 49
# Considered failure.
# True: Te=0.063, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.767e-10]
#            x: [ 9.693e-01]
#         cost: 1.560760928142595e-20
#          jac: [[ 4.485e-02]]
#         grad: [ 7.924e-12]
#   optimality: 7.680388975496348e-12
#  active_mask: [0]
#         nfev: 49
#         njev: 49
# Considered failure.
# True: Te=0.067, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.875e-10]
#            x: [ 9.714e-01]
#         cost: 1.7580750710352938e-20
#          jac: [[ 5.570e-02]]
#         grad: [ 1.045e-11]
#   optimality: 1.0146555389372382e-11
#  active_mask: [0]
#         nfev: 49
#         njev: 49
# Considered failure.
# True: Te=0.070, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.555e-10]
#            x: [ 9.734e-01]
#         cost: 1.0372754223072767e-19
#          jac: [[ 8.987e-02]]
#         grad: [ 4.093e-11]
#   optimality: 3.984330816519758e-11
#  active_mask: [0]
#         nfev: 48
#         njev: 48
# Considered failure.
# True: Te=0.074, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.749e-10]
#            x: [ 9.752e-01]
#         cost: 1.1274556163085034e-19
#          jac: [[ 1.106e-01]]
#         grad: [ 5.252e-11]
#   optimality: 5.12218743820136e-11
#  active_mask: [0]
#         nfev: 48
#         njev: 48
# Considered failure.
# True: Te=0.078, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.013e-10]
#            x: [ 9.770e-01]
#         cost: 1.2566152937712363e-19
#          jac: [[ 1.372e-01]]
#         grad: [ 6.880e-11]
#   optimality: 6.72118701141474e-11
#  active_mask: [0]
#         nfev: 48
#         njev: 48
# Considered failure.
# True: Te=0.082, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.358e-10]
#            x: [ 9.786e-01]
#         cost: 1.4355348656469236e-19
#          jac: [[ 1.716e-01]]
#         grad: [ 9.192e-11]
#   optimality: 8.995503537829456e-11
#  active_mask: [0]
#         nfev: 48
#         njev: 48
# Considered failure.
# True: Te=0.086, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.284e-09]
#            x: [ 9.801e-01]
#         cost: 8.240329451919836e-19
#          jac: [[ 2.752e-01]]
#         grad: [ 3.533e-10]
#   optimality: 3.462977739340631e-10
#  active_mask: [0]
#         nfev: 47
#         njev: 47
# Considered failure.
# True: Te=0.090, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.348e-09]
#            x: [ 9.815e-01]
#         cost: 9.086833335619379e-19
#          jac: [[ 3.410e-01]]
#         grad: [ 4.597e-10]
#   optimality: 4.511431251749522e-10
#  active_mask: [0]
#         nfev: 47
#         njev: 47
# Considered failure.
# True: Te=0.095, n0=3.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.434e-09]
#            x: [ 9.828e-01]
#         cost: 1.0276316769422033e-18
#          jac: [[ 4.257e-01]]
#         grad: [ 6.103e-10]
#   optimality: 5.997869540924535e-10
#  active_mask: [0]
#         nfev: 47
#         njev: 47

# %%
fig, ax = plt.subplots(figsize=(10,6))

# colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

colors = plt.cm.plasma(np.linspace(0, 1,len(Saha_list))) #plt.cycler("color", plt.cm.jet(np.linspace(0,1,len(Saha_list))))



ax.set_ylabel(r"$\langle Z \rangle$")#,color=colors[0])
ax.set_xlabel("T [K]")
ax.set_xscale('log')

ax2 = ax.twinx()
# ax2.plot(T_K_array, Δχ_Saha*AU_to_eV,'--.',color=colors[1])
ax2.set_ylabel(r"$\Delta \chi$ [eV]")#,color=colors[1])

for i, (Zbar_0, Saha) in enumerate(zip(Zbar_0_list, Saha_list)):
    if i==0:
        try:
            ax.plot(T_K_array, Saha[0],'-' , color=colors[i], label=f'Initial guess, Zbar= {Zbar_0:0.3f}')
            ax2.plot(T_K_array, Saha[1]*AU_to_eV,':' , color=colors[i], label=r'$\chi_0$')
        except TypeError:
            pass
            
    else:
        try:
            ax.plot(T_K_array, Saha[0],'-' , color=colors[i])#, label=f'Initial guess, Zbar= {Zbar_0:0.3f}')
            ax2.plot(T_K_array, Saha[1]*AU_to_eV,':' , color=colors[i])
        except TypeError:
            pass
            
# ax2.plot(T_K_array, Δχ_Saha_1*AU_to_eV,'-' ,color=colors[1])

ax2.plot(T_K_array, np.ones_like(T_K_array)*χ0_AU*AU_to_eV,'-' ,color='k')
ax2.text(np.min(T_K_array)*1.2, 1.01*χ0_AU*AU_to_eV, r"$\chi_0$ = {0:0.1f} [eV]".format(χ0_AU*AU_to_eV), fontsize=12,
        verticalalignment='bottom')#, bbox=props)

# Adding a manual colorbar
sm = plt.cm.ScalarMappable(cmap='plasma', norm=plt.Normalize(vmin=0, vmax=1))
sm.set_array([])
fig.colorbar(sm, ax=[ax, ax2], orientation='vertical', label=r'$\langle Z\rangle^{\rm initial guess}$')

plt.subplots_adjust(right=0.7)

# text
props = dict(boxstyle='round', facecolor='white', alpha=0.5)
inset_text = f"{element} at n = {n0_invcc:0.2e} [1/cc]"
ax.text(0.15, 0.95, inset_text, transform=ax.transAxes, fontsize=12,
        verticalalignment='top', bbox=props)

ax.set_ylim(1e-4,1.2)
ax2.set_ylim(1e-4,1.2*χ0_AU*AU_to_eV)

ax.set_yscale('log')
ax2.set_yscale('log')
ax.legend()
# plt.tight_layout()

# ax.set_yscale('log')

# %%
# Fix nan, None issues...

Zbar_list = np.array([Saha[0] for Saha in Saha_list])
χ0_list   = np.array([Saha[1] for Saha in Saha_list])
Zbar_mean, Zbar_std = np.nanmean(Zbar_list,axis=0), np.nanstd(Zbar_list,axis=0) 
χ0_mean, χ0_std = np.nanmean(χ0_list,axis=0), np.nanstd(χ0_list,axis=0)

# %%
fig, ax = plt.subplots(figsize=(10,6))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

ax.set_ylabel(r"$\langle Z \rangle$",color=colors[0])
ax.set_xlabel("T [K]")
ax.set_xscale('log')

ax2 = ax.twinx()
ax2.set_ylabel(r"$\Delta \chi$ [eV]",color=colors[1])

# Plot mean and Std
ax.plot(T_K_array, Zbar_mean,'-' , color=colors[0])#, label=f'Initial guess')
ax.fill_between(T_K_array, Zbar_mean - Zbar_std, Zbar_mean + Zbar_std, color=colors[0], alpha=0.2)
ax2.plot(T_K_array, χ0_mean*AU_to_eV,'-' , color=colors[1])#, label=r'$\chi_0$')
ax2.fill_between(T_K_array, (χ0_mean - χ0_std)*AU_to_eV, (χ0_mean + χ0_std)*AU_to_eV, color=colors[1], alpha=0.2, linestyle='-')
           

# Plot all actual solution output    
colors = plt.cm.plasma(np.linspace(0, 1,len(Saha_list))) #plt.cycler("color", plt.cm.jet(np.linspace(0,1,len(Saha_list))))

for i, (Zbar_0, Saha) in enumerate(zip(Zbar_0_list, Saha_list)):
    if i==0:
        try:
            ax.plot(T_K_array, Saha[0],'^' , color=colors[i], label=f'Solution for colorbar initial guess', alpha=0.1, markersize=5)
            ax2.plot(T_K_array, Saha[1]*AU_to_eV,'^' , color=colors[i], label=r'$\chi_0$', alpha=0.1, markersize=5)
        except TypeError:
            pass
            
    else:
        try:
            ax.plot(T_K_array, Saha[0],'^' , color=colors[i],alpha=0.1, markersize=5)
            ax2.plot(T_K_array, Saha[1]*AU_to_eV,'^' , color=colors[i],alpha=0.1, markersize=5)
        except TypeError:
            pass


# Plot χ0 Line
ax2.plot(T_K_array, np.ones_like(T_K_array)*χ0_AU*AU_to_eV,'-' ,color='k')
ax2.text(np.min(T_K_array)*1.2, 1.01*χ0_AU*AU_to_eV, r"$\chi_0$ = {0:0.1f} [eV]".format(χ0_AU*AU_to_eV), fontsize=12,
        verticalalignment='bottom')#, bbox=props)

# Adding a manual colorbar
sm = plt.cm.ScalarMappable(cmap='plasma', norm=plt.Normalize(vmin=0, vmax=1))
sm.set_array([])
fig.colorbar(sm, ax=[ax, ax2], orientation='vertical', label=r'$\langle Z\rangle^{\rm initial guess}$')

plt.subplots_adjust(right=0.7)

# text
props = dict(boxstyle='round', facecolor='white', alpha=0.5)
inset_text = f"{element} at n = {n0_invcc:0.2e} [1/cc]"
ax.text(0.15, 0.95, inset_text, transform=ax.transAxes, fontsize=12,
        verticalalignment='top', bbox=props)

ax.set_ylim(1e-7,10)
ax2.set_ylim(1e-3,10*χ0_AU*AU_to_eV)

ax.set_yscale('log')
ax2.set_yscale('log')
ax.legend()
# plt.tight_layout()

# ax.set_yscale('log')

# %% [markdown]
# ## Helium

# %%
element='He'
g1 = 2 # easy, right? 2 electrons in s-shell, can remove up or down?
g0 = 1
χ0_eV = 24.587387936 # eV
χ0_AU = χ0_eV*eV_to_AU

n0_invcc = 1.83e21
n0_AU = n0_invcc*invcc_to_AU

# array
T_K_array = np.geomspace(1e3, 1e5, num=100)
Zbar_0_list = np.linspace(1e-6,1-1e-6, num=20)
Saha_list = [ solve_Saha(T_K_array*K_to_AU, n0_AU, Zbar_0=Zbar_0) for Zbar_0 in Zbar_0_list]
# Out:
# Considered failure.
# True: Te=0.039, n0=2.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.125e-19]
#            x: [ 1.149e-29]
#         cost: 8.506889745998778e-38
#          jac: [[ 5.117e-14]]
#         grad: [ 2.111e-32]
#   optimality: 2.426044659933602e-61
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.041, n0=2.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.888e-18]
#            x: [ 4.941e-324]
#         cost: 7.556849928606172e-36
#          jac: [[ 4.498e-13]]
#         grad: [ 1.749e-30]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.043, n0=2.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.330e-17]
#            x: [ 1.500e-28]
#         cost: 5.544400010033698e-34
#          jac: [[ 3.594e-12]]
#         grad: [ 1.197e-28]
#   optimality: 1.7950326065959415e-56
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.045, n0=2.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.604e-16]
#            x: [ 4.941e-324]
#         cost: 3.389121294050935e-32
#          jac: [[ 2.620e-11]]
#         grad: [ 6.822e-27]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.047, n0=2.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.866e-15]
#            x: [ 5.874e-33]
#         cost: 1.7403713296777163e-30
#          jac: [[ 1.751e-10]]
#         grad: [ 3.267e-25]
#   optimality: 1.918915790485084e-57
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.049, n0=2.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.230e-14]
#            x: [ 1.802e-28]
#         cost: 7.567608394968777e-29
#          jac: [[ 1.077e-09]]
#         grad: [ 1.325e-23]
#   optimality: 2.38683448163011e-51
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.052, n0=2.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.493e-14]
#            x: [ 4.941e-324]
#         cost: 2.8075056212576564e-27
#          jac: [[ 6.116e-09]]
#         grad: [ 4.583e-22]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.054, n0=2.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.231e-13]
#            x: [ 6.828e-29]
#         cost: 8.950802456996495e-26
#          jac: [[ 3.221e-08]]
#         grad: [ 1.363e-20]
#   optimality: 9.303414243685491e-49
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.057, n0=2.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.222e-12]
#            x: [ 7.559e-29]
#         cost: 2.4693026019708703e-24
#          jac: [[ 1.577e-07]]
#         grad: [ 3.506e-19]
#   optimality: 2.6499414322805396e-47
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.059, n0=2.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.089e-11]
#            x: [ 4.941e-324]
#         cost: 5.93353261911294e-23
#          jac: [[ 7.211e-07]]
#         grad: [ 7.856e-18]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.062, n0=2.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.999e-11]
#            x: [ 4.529e-29]
#         cost: 1.2496975342955813e-21
#          jac: [[ 3.086e-06]]
#         grad: [ 1.543e-16]
#   optimality: 6.988124257728781e-45
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.065, n0=2.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.154e-10]
#            x: [ 1.505e-36]
#         cost: 2.320871175776749e-20
#          jac: [[ 1.240e-05]]
#         grad: [ 2.672e-15]
#   optimality: 4.0208688106848707e-51
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.068, n0=2.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 8.743e-10]
#            x: [ 1.204e-29]
#         cost: 3.8223937312620485e-19
#          jac: [[ 4.694e-05]]
#         grad: [ 4.104e-14]
#   optimality: 4.943217099402729e-43
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.071, n0=2.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.351e-09]
#            x: [ 2.027e-29]
#         cost: 5.613437614374825e-18
#          jac: [[ 1.678e-04]]
#         grad: [ 5.621e-13]
#   optimality: 1.1393373621243653e-41
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.075, n0=2.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.216e-08]
#            x: [ 4.941e-324]
#         cost: 7.389151126942189e-17
#          jac: [[ 5.676e-04]]
#         grad: [ 6.901e-12]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.078, n0=2.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.186e-08]
#            x: [ 5.064e-30]
#         cost: 8.761784744363608e-16
#          jac: [[ 1.823e-03]]
#         grad: [ 7.631e-11]
#   optimality: 3.863944983132859e-40
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.082, n0=2.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.371e-07]
#            x: [ 6.432e-30]
#         cost: 9.403402366256974e-15
#          jac: [[ 5.569e-03]]
#         grad: [ 7.638e-10]
#   optimality: 4.912519365863646e-39
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.086, n0=2.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.284e-07]
#            x: [ 2.392e-31]
#         cost: 9.175720494862125e-14
#          jac: [[ 1.622e-02]]
#         grad: [ 6.950e-09]
#   optimality: 1.662764662251925e-39
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.090, n0=2.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.279e-06]
#            x: [ 4.941e-324]
#         cost: 8.175924856245009e-13
#          jac: [[ 4.516e-02]]
#         grad: [ 5.775e-08]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.094, n0=2.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.655e-06]
#            x: [ 8.875e-30]
#         cost: 6.679879264835559e-12
#          jac: [[ 1.204e-01]]
#         grad: [ 4.401e-07]
#   optimality: 3.905388227092837e-36
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.099, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.002e-05]
#            x: [ 2.004e-30]
#         cost: 5.023972724283954e-11
#          jac: [[ 3.079e-01]]
#         grad: [ 3.087e-06]
#   optimality: 6.184607746699187e-36
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.104, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 2.643e-05]
#            x: [ 3.331e-30]
#         cost: 3.49145937680227e-10
#          jac: [[ 7.570e-01]]
#         grad: [ 2.000e-05]
#   optimality: 6.664343742340883e-35
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.109, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 6.708e-05]
#            x: [ 4.941e-324]
#         cost: 2.250130068189139e-09
#          jac: [[ 1.792e+00]]
#         grad: [ 1.202e-04]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.114, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.643e-04]
#            x: [ 6.230e-30]
#         cost: 1.3493919449172249e-08
#          jac: [[ 4.093e+00]]
#         grad: [ 6.724e-04]
#   optimality: 4.189344147639939e-33
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.119, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 3.887e-04]
#            x: [ 4.941e-324]
#         cost: 7.55474378659398e-08
#          jac: [[ 9.032e+00]]
#         grad: [ 3.511e-03]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.125, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 8.901e-04]
#            x: [ 4.941e-324]
#         cost: 3.961039565697853e-07
#          jac: [[ 1.929e+01]]
#         grad: [ 1.717e-02]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.131, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.975e-03]
#            x: [ 4.941e-324]
#         cost: 1.9507492478266612e-06
#          jac: [[ 3.992e+01]]
#         grad: [ 7.884e-02]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.137, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 4.254e-03]
#            x: [ 8.896e-31]
#         cost: 9.049669038318111e-06
#          jac: [[ 8.018e+01]]
#         grad: [ 3.411e-01]
#   optimality: 3.0345189854149144e-31
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.144, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 8.905e-03]
#            x: [ 4.941e-324]
#         cost: 3.965362491821587e-05
#          jac: [[ 1.565e+02]]
#         grad: [ 1.394e+00]
#   optimality: 5e-324
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.150, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.814e-02]
#            x: [ 3.673e-40]
#         cost: 0.00016454260861093354
#          jac: [[ 2.974e+02]]
#         grad: [ 5.394e+00]
#   optimality: 1.9815251180177464e-39
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.158, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 3.600e-02]
#            x: [ 4.085e-31]
#         cost: 0.0006481780076666414
#          jac: [[ 5.504e+02]]
#         grad: [ 1.982e+01]
#   optimality: 8.094762820890578e-30
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.165, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 6.971e-02]
#            x: [ 8.036e-31]
#         cost: 0.0024297238164775596
#          jac: [[ 9.938e+02]]
#         grad: [ 6.928e+01]
#   optimality: 5.567298888834303e-29
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.173, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.318e-01]
#            x: [ 4.941e-324]
#         cost: 0.008686520844657873
#          jac: [[ 1.752e+03]]
#         grad: [ 2.310e+02]
#   optimality: 1.14e-321
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.181, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 2.436e-01]
#            x: [ 4.941e-324]
#         cost: 0.029682211999241807
#          jac: [[ 3.021e+03]]
#         grad: [ 7.361e+02]
#   optimality: 3.636e-321
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.190, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 4.408e-01]
#            x: [ 1.898e-31]
#         cost: 0.09714058240478514
#          jac: [[ 5.097e+03]]
#         grad: [ 2.247e+03]
#   optimality: 4.2640259898170695e-28
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.199, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 7.811e-01]
#            x: [ 4.941e-324]
#         cost: 0.3050782312208684
#          jac: [[ 8.424e+03]]
#         grad: [ 6.580e+03]
#   optimality: 3.251e-320
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.208, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.357e+00]
#            x: [ 4.502e-31]
#         cost: 0.9211728291001383
#          jac: [[ 1.365e+04]]
#         grad: [ 1.853e+04]
#   optimality: 8.342411706699107e-27
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.218, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 2.315e+00]
#            x: [ 4.941e-324]
#         cost: 2.678963167593056
#          jac: [[ 2.171e+04]]
#         grad: [ 5.025e+04]
#   optimality: 2.4829e-319
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.229, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 3.877e+00]
#            x: [ 4.941e-324]
#         cost: 7.51673333871062
#          jac: [[ 3.392e+04]]
#         grad: [ 1.315e+05]
#   optimality: 6.497e-319
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.240, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 6.385e+00]
#            x: [ 1.269e-31]
#         cost: 20.38147896124411
#          jac: [[ 5.208e+04]]
#         grad: [ 3.325e+05]
#   optimality: 4.219545513524648e-26
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.251, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.034e+01]
#            x: [ 4.941e-324]
#         cost: 53.48864766483993
#          jac: [[ 7.869e+04]]
#         grad: [ 8.139e+05]
#   optimality: 4.02101e-318
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.263, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.650e+01]
#            x: [ 4.941e-324]
#         cost: 136.06657214338412
#          jac: [[ 1.170e+05]]
#         grad: [ 1.931e+06]
#   optimality: 9.539385e-318
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.275, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 2.592e+01]
#            x: [ 4.941e-324]
#         cost: 335.9854028925499
#          jac: [[ 1.715e+05]]
#         grad: [ 4.446e+06]
#   optimality: 2.1967705e-317
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.289, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 4.016e+01]
#            x: [ 1.257e-32]
#         cost: 806.4097830809881
#          jac: [[ 2.478e+05]]
#         grad: [ 9.952e+06]
#   optimality: 1.250609910585236e-25
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.302, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 6.138e+01]
#            x: [ 4.535e-30]
#         cost: 1883.72785279008
#          jac: [[ 3.532e+05]]
#         grad: [ 2.168e+07]
#   optimality: 9.831643911020753e-23
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.317, n0=2.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 9.261e+01]
#            x: [ 5.890e-33]
#         cost: 4287.880025129507
#          jac: [[ 4.970e+05]]
#         grad: [ 4.603e+07]
#   optimality: 2.710812066802998e-25
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# Considered failure.
# True: Te=0.125, n0=2.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 8.901e-04]
#            x: [ 9.343e-28]
#         cost: 3.961039565698486e-07
#          jac: [[ 1.929e+01]]
#         grad: [ 1.717e-02]
#   optimality: 1.603929265824833e-29
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.131, n0=2.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.975e-03]
#            x: [ 2.480e-27]
#         cost: 1.9507492478271313e-06
#          jac: [[ 3.992e+01]]
#         grad: [ 7.884e-02]
#   optimality: 1.955537762979725e-28
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.137, n0=2.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.254e-03]
#            x: [ 1.468e-28]
#         cost: 9.04966903831859e-06
#          jac: [[ 8.018e+01]]
#         grad: [ 3.411e-01]
#   optimality: 5.0059173275657753e-29
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.144, n0=2.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 8.905e-03]
#            x: [ 1.233e-32]
#         cost: 3.965362491821587e-05
#          jac: [[ 1.565e+02]]
#         grad: [ 1.394e+00]
#   optimality: 1.7181491141638566e-32
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.150, n0=2.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.814e-02]
#            x: [ 3.081e-33]
#         cost: 0.00016454260861093354
#          jac: [[ 2.974e+02]]
#         grad: [ 5.394e+00]
#   optimality: 1.6622237457204611e-32
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.158, n0=2.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.600e-02]
#            x: [ 2.021e-27]
#         cost: 0.0006481780076667476
#          jac: [[ 5.504e+02]]
#         grad: [ 1.982e+01]
#   optimality: 4.0060057418089355e-26
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.165, n0=2.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 6.971e-02]
#            x: [ 4.941e-324]
#         cost: 0.002429723816477551
#          jac: [[ 9.938e+02]]
#         grad: [ 6.928e+01]
#   optimality: 3.4e-322
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.173, n0=2.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.318e-01]
#            x: [ 2.793e-33]
#         cost: 0.008686520844657873
#          jac: [[ 1.752e+03]]
#         grad: [ 2.310e+02]
#   optimality: 6.450388643598005e-31
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.181, n0=2.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.436e-01]
#            x: [ 2.407e-35]
#         cost: 0.029682211999241807
#          jac: [[ 3.021e+03]]
#         grad: [ 7.361e+02]
#   optimality: 1.7720352625993915e-32
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.190, n0=2.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.408e-01]
#            x: [ 4.941e-324]
#         cost: 0.09714058240478475
#          jac: [[ 5.097e+03]]
#         grad: [ 2.247e+03]
#   optimality: 1.11e-320
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.199, n0=2.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.811e-01]
#            x: [ 4.941e-324]
#         cost: 0.3050782312208684
#          jac: [[ 8.424e+03]]
#         grad: [ 6.580e+03]
#   optimality: 3.251e-320
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.208, n0=2.7e-04, Zbar_0=0.053
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.357e+00]
#            x: [ 1.287e-29]
#         cost: 0.9211728291001446
#          jac: [[ 1.365e+04]]
#         grad: [ 1.853e+04]
#   optimality: 2.385298848657038e-25
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.218, n0=2.7e-04, Zbar_0=0.053
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 2.315e+00]
#            x: [ 4.941e-324]
#         cost: 2.678963167593056
#          jac: [[ 2.171e+04]]
#         grad: [ 5.025e+04]
#   optimality: 2.4829e-319
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.229, n0=2.7e-04, Zbar_0=0.053
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 3.877e+00]
#            x: [ 4.941e-324]
#         cost: 7.51673333871062
#          jac: [[ 3.392e+04]]
#         grad: [ 1.315e+05]
#   optimality: 6.497e-319
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.240, n0=2.7e-04, Zbar_0=0.053
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 6.385e+00]
#            x: [ 5.841e-31]
#         cost: 20.381478961244138
#          jac: [[ 5.208e+04]]
#         grad: [ 3.325e+05]
#   optimality: 1.942346430938293e-25
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.251, n0=2.7e-04, Zbar_0=0.053
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.034e+01]
#            x: [ 3.918e-31]
#         cost: 53.48864766483999
#          jac: [[ 7.869e+04]]
#         grad: [ 8.139e+05]
#   optimality: 3.1891046686887477e-25
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.263, n0=2.7e-04, Zbar_0=0.053
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.650e+01]
#            x: [ 1.838e-32]
#         cost: 136.06657214338412
#          jac: [[ 1.170e+05]]
#         grad: [ 1.931e+06]
#   optimality: 3.5489040338762426e-26
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.275, n0=2.7e-04, Zbar_0=0.053
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 2.592e+01]
#            x: [ 4.941e-324]
#         cost: 335.9854028925499
#          jac: [[ 1.715e+05]]
#         grad: [ 4.446e+06]
#   optimality: 2.1967705e-317
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.289, n0=2.7e-04, Zbar_0=0.053
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 4.016e+01]
#            x: [ 4.192e-32]
#         cost: 806.4097830809881
#          jac: [[ 2.478e+05]]
#         grad: [ 9.952e+06]
#   optimality: 4.17162551723975e-25
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.302, n0=2.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 6.138e+01]
#            x: [ 3.669e-27]
#         cost: 1883.727852790234
#          jac: [[ 3.532e+05]]
#         grad: [ 2.168e+07]
#   optimality: 7.955185122762905e-20
#  active_mask: [-1]
#         nfev: 7
#         njev: 7
# Considered failure.
# True: Te=0.317, n0=2.7e-04, Zbar_0=0.053
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 9.261e+01]
#            x: [ 4.941e-324]
#         cost: 4287.880025129507
#          jac: [[ 4.970e+05]]
#         grad: [ 4.603e+07]
#   optimality: 2.2740173e-316
#  active_mask: [-1]
#         nfev: 7
#         njev: 7
# Considered failure.
# True: Te=0.137, n0=2.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.254e-03]
#            x: [ 1.414e-28]
#         cost: 9.04966903831859e-06
#          jac: [[ 8.018e+01]]
#         grad: [ 3.411e-01]
#   optimality: 4.823040249073818e-29
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.144, n0=2.7e-04, Zbar_0=0.105
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 8.905e-03]
#            x: [ 2.516e-31]
#         cost: 3.965362491821598e-05
#          jac: [[ 1.565e+02]]
#         grad: [ 1.394e+00]
#   optimality: 3.507106839784897e-31
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.150, n0=2.7e-04, Zbar_0=0.105
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.814e-02]
#            x: [ 1.433e-30]
#         cost: 0.00016454260861093462
#          jac: [[ 2.974e+02]]
#         grad: [ 5.394e+00]
#   optimality: 7.729161232143915e-30
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.158, n0=2.7e-04, Zbar_0=0.105
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 3.600e-02]
#            x: [ 4.941e-324]
#         cost: 0.0006481780076666391
#          jac: [[ 5.504e+02]]
#         grad: [ 1.982e+01]
#   optimality: 1e-322
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.165, n0=2.7e-04, Zbar_0=0.105
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 6.971e-02]
#            x: [ 4.941e-324]
#         cost: 0.002429723816477551
#          jac: [[ 9.938e+02]]
#         grad: [ 6.928e+01]
#   optimality: 3.4e-322
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.173, n0=2.7e-04, Zbar_0=0.105
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.318e-01]
#            x: [ 4.941e-324]
#         cost: 0.008686520844657873
#          jac: [[ 1.752e+03]]
#         grad: [ 2.310e+02]
#   optimality: 1.14e-321
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.181, n0=2.7e-04, Zbar_0=0.105
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 2.436e-01]
#            x: [ 1.160e-31]
#         cost: 0.029682211999241807
#          jac: [[ 3.021e+03]]
#         grad: [ 7.361e+02]
#   optimality: 8.536345967418202e-29
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.190, n0=2.7e-04, Zbar_0=0.105
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 4.408e-01]
#            x: [ 4.941e-324]
#         cost: 0.09714058240478475
#          jac: [[ 5.097e+03]]
#         grad: [ 2.247e+03]
#   optimality: 1.11e-320
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.199, n0=2.7e-04, Zbar_0=0.105
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 7.811e-01]
#            x: [ 2.375e-33]
#         cost: 0.3050782312208684
#          jac: [[ 8.424e+03]]
#         grad: [ 6.580e+03]
#   optimality: 1.5624816864271765e-29
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.208, n0=2.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.357e+00]
#            x: [ 1.030e-26]
#         cost: 0.9211728291003674
#          jac: [[ 1.365e+04]]
#         grad: [ 1.853e+04]
#   optimality: 1.9089643457270299e-22
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.218, n0=2.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.315e+00]
#            x: [ 4.584e-30]
#         cost: 2.678963167593065
#          jac: [[ 2.171e+04]]
#         grad: [ 5.025e+04]
#   optimality: 2.303498280919905e-25
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.229, n0=2.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.877e+00]
#            x: [ 1.066e-27]
#         cost: 7.516733338711159
#          jac: [[ 3.392e+04]]
#         grad: [ 1.315e+05]
#   optimality: 1.4013608039618924e-22
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.240, n0=2.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 6.385e+00]
#            x: [ 4.511e-32]
#         cost: 20.38147896124411
#          jac: [[ 5.208e+04]]
#         grad: [ 3.325e+05]
#   optimality: 1.5002010802792622e-26
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.251, n0=2.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.034e+01]
#            x: [ 7.060e-29]
#         cost: 53.488647664840755
#          jac: [[ 7.869e+04]]
#         grad: [ 8.139e+05]
#   optimality: 5.745507007560714e-23
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.263, n0=2.7e-04, Zbar_0=0.105
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.650e+01]
#            x: [ 2.882e-29]
#         cost: 136.06657214338543
#          jac: [[ 1.170e+05]]
#         grad: [ 1.931e+06]
#   optimality: 5.565239812487247e-23
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.275, n0=2.7e-04, Zbar_0=0.105
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 2.592e+01]
#            x: [ 1.035e-29]
#         cost: 335.98540289255163
#          jac: [[ 1.715e+05]]
#         grad: [ 4.446e+06]
#   optimality: 4.600520042136504e-23
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.289, n0=2.7e-04, Zbar_0=0.105
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 4.016e+01]
#            x: [ 1.472e-30]
#         cost: 806.4097830809881
#          jac: [[ 2.478e+05]]
#         grad: [ 9.952e+06]
#   optimality: 1.4650038279402972e-23
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.302, n0=2.7e-04, Zbar_0=0.105
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 6.138e+01]
#            x: [ 2.351e-38]
#         cost: 1883.7278527900735
#          jac: [[ 3.532e+05]]
#         grad: [ 2.168e+07]
#   optimality: 5.0972914917692265e-31
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.317, n0=2.7e-04, Zbar_0=0.105
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 9.261e+01]
#            x: [ 3.262e-30]
#         cost: 4287.880025129514
#          jac: [[ 4.970e+05]]
#         grad: [ 4.603e+07]
#   optimality: 1.5012369513982553e-22
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.150, n0=2.7e-04, Zbar_0=0.158
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.814e-02]
#            x: [ 4.941e-324]
#         cost: 0.00016454260861093354
#          jac: [[ 2.974e+02]]
#         grad: [ 5.394e+00]
#   optimality: 2.5e-323
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.158, n0=2.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.600e-02]
#            x: [ 6.247e-29]
#         cost: 0.0006481780076666579
#          jac: [[ 5.504e+02]]
#         grad: [ 1.982e+01]
#   optimality: 1.238060700998737e-27
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.165, n0=2.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 6.971e-02]
#            x: [ 1.505e-36]
#         cost: 0.002429723816477551
#          jac: [[ 9.938e+02]]
#         grad: [ 6.928e+01]
#   optimality: 1.0423776572264762e-34
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.173, n0=2.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.318e-01]
#            x: [ 4.941e-324]
#         cost: 0.008686520844657873
#          jac: [[ 1.752e+03]]
#         grad: [ 2.310e+02]
#   optimality: 1.14e-321
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.181, n0=2.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.436e-01]
#            x: [ 4.941e-324]
#         cost: 0.029682211999241807
#          jac: [[ 3.021e+03]]
#         grad: [ 7.361e+02]
#   optimality: 3.636e-321
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.190, n0=2.7e-04, Zbar_0=0.158
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 4.408e-01]
#            x: [ 1.475e-29]
#         cost: 0.09714058240478585
#          jac: [[ 5.097e+03]]
#         grad: [ 2.247e+03]
#   optimality: 3.3143822073878675e-26
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.199, n0=2.7e-04, Zbar_0=0.158
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 7.811e-01]
#            x: [ 5.877e-39]
#         cost: 0.3050782312208684
#          jac: [[ 8.424e+03]]
#         grad: [ 6.580e+03]
#   optimality: 3.867373197091994e-35
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.208, n0=2.7e-04, Zbar_0=0.158
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.357e+00]
#            x: [ 4.941e-324]
#         cost: 0.9211728291001383
#          jac: [[ 1.365e+04]]
#         grad: [ 1.853e+04]
#   optimality: 9.1545e-320
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.218, n0=2.7e-04, Zbar_0=0.158
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 2.315e+00]
#            x: [ 3.918e-31]
#         cost: 2.678963167593065
#          jac: [[ 2.171e+04]]
#         grad: [ 5.025e+04]
#   optimality: 1.9687844189242214e-26
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.229, n0=2.7e-04, Zbar_0=0.158
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 3.877e+00]
#            x: [ 1.915e-31]
#         cost: 7.51673333871062
#          jac: [[ 3.392e+04]]
#         grad: [ 1.315e+05]
#   optimality: 2.517852208868251e-26
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.240, n0=2.7e-04, Zbar_0=0.158
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 6.385e+00]
#            x: [ 9.654e-32]
#         cost: 20.38147896124411
#          jac: [[ 5.208e+04]]
#         grad: [ 3.325e+05]
#   optimality: 3.2102051206269545e-26
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.251, n0=2.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.034e+01]
#            x: [ 9.618e-27]
#         cost: 53.4886476648497
#          jac: [[ 7.869e+04]]
#         grad: [ 8.139e+05]
#   optimality: 7.827901813149156e-21
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.263, n0=2.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.650e+01]
#            x: [ 4.941e-324]
#         cost: 136.06657214338412
#          jac: [[ 1.170e+05]]
#         grad: [ 1.931e+06]
#   optimality: 9.539385e-318
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.275, n0=2.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.592e+01]
#            x: [ 4.059e-29]
#         cost: 335.98540289255345
#          jac: [[ 1.715e+05]]
#         grad: [ 4.446e+06]
#   optimality: 1.8049354351819038e-22
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.289, n0=2.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.016e+01]
#            x: [ 7.418e-28]
#         cost: 806.4097830810211
#          jac: [[ 2.478e+05]]
#         grad: [ 9.952e+06]
#   optimality: 7.382468487916448e-21
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.302, n0=2.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 6.138e+01]
#            x: [ 2.151e-31]
#         cost: 1883.7278527900735
#          jac: [[ 3.532e+05]]
#         grad: [ 2.168e+07]
#   optimality: 4.663736266645303e-24
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.317, n0=2.7e-04, Zbar_0=0.158
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 9.261e+01]
#            x: [ 4.941e-324]
#         cost: 4287.880025129507
#          jac: [[ 4.970e+05]]
#         grad: [ 4.603e+07]
#   optimality: 2.2740173e-316
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.158, n0=2.7e-04, Zbar_0=0.211
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 3.600e-02]
#            x: [ 4.941e-324]
#         cost: 0.0006481780076666391
#          jac: [[ 5.504e+02]]
#         grad: [ 1.982e+01]
#   optimality: 1e-322
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.165, n0=2.7e-04, Zbar_0=0.211
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 6.971e-02]
#            x: [ 5.737e-28]
#         cost: 0.002429723816477758
#          jac: [[ 9.938e+02]]
#         grad: [ 6.928e+01]
#   optimality: 3.9747150942566836e-26
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.173, n0=2.7e-04, Zbar_0=0.211
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.318e-01]
#            x: [ 1.979e-28]
#         cost: 0.008686520844658272
#          jac: [[ 1.752e+03]]
#         grad: [ 2.310e+02]
#   optimality: 4.5707053554290804e-26
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.181, n0=2.7e-04, Zbar_0=0.211
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.436e-01]
#            x: [ 5.778e-34]
#         cost: 0.029682211999241807
#          jac: [[ 3.021e+03]]
#         grad: [ 7.361e+02]
#   optimality: 4.25288463023854e-31
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.190, n0=2.7e-04, Zbar_0=0.211
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.408e-01]
#            x: [ 2.917e-28]
#         cost: 0.09714058240478962
#          jac: [[ 5.097e+03]]
#         grad: [ 2.247e+03]
#   optimality: 6.553015984592973e-25
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.199, n0=2.7e-04, Zbar_0=0.211
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.811e-01]
#            x: [ 4.815e-35]
#         cost: 0.3050782312208684
#          jac: [[ 8.424e+03]]
#         grad: [ 6.580e+03]
#   optimality: 3.1681521230577613e-31
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.208, n0=2.7e-04, Zbar_0=0.211
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.357e+00]
#            x: [ 1.752e-28]
#         cost: 0.9211728291001678
#          jac: [[ 1.365e+04]]
#         grad: [ 1.853e+04]
#   optimality: 3.246865978662794e-24
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.218, n0=2.7e-04, Zbar_0=0.211
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 2.315e+00]
#            x: [ 1.881e-37]
#         cost: 2.678963167593056
#          jac: [[ 2.171e+04]]
#         grad: [ 5.025e+04]
#   optimality: 9.451722857095094e-33
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.229, n0=2.7e-04, Zbar_0=0.211
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 3.877e+00]
#            x: [ 2.351e-38]
#         cost: 7.51673333871062
#          jac: [[ 3.392e+04]]
#         grad: [ 1.315e+05]
#   optimality: 3.091564538567858e-33
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.240, n0=2.7e-04, Zbar_0=0.211
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 6.385e+00]
#            x: [ 4.941e-324]
#         cost: 20.38147896124411
#          jac: [[ 5.208e+04]]
#         grad: [ 3.325e+05]
#   optimality: 1.64291e-318
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.251, n0=2.7e-04, Zbar_0=0.211
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.034e+01]
#            x: [ 2.207e-31]
#         cost: 53.48864766483993
#          jac: [[ 7.869e+04]]
#         grad: [ 8.139e+05]
#   optimality: 1.7964505336217378e-25
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.263, n0=2.7e-04, Zbar_0=0.211
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.650e+01]
#            x: [ 4.115e-31]
#         cost: 136.06657214338435
#          jac: [[ 1.170e+05]]
#         grad: [ 1.931e+06]
#   optimality: 7.945995685276535e-25
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.275, n0=2.7e-04, Zbar_0=0.211
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 2.592e+01]
#            x: [ 1.333e-30]
#         cost: 335.98540289255044
#          jac: [[ 1.715e+05]]
#         grad: [ 4.446e+06]
#   optimality: 5.928204597596941e-24
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.289, n0=2.7e-04, Zbar_0=0.211
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 4.016e+01]
#            x: [ 4.941e-324]
#         cost: 806.4097830809881
#          jac: [[ 2.478e+05]]
#         grad: [ 9.952e+06]
#   optimality: 4.917174e-317
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.302, n0=2.7e-04, Zbar_0=0.211
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 6.138e+01]
#            x: [ 1.054e-26]
#         cost: 1883.7278527903475
#          jac: [[ 3.532e+05]]
#         grad: [ 2.168e+07]
#   optimality: 2.284361763545147e-19
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.317, n0=2.7e-04, Zbar_0=0.211
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 9.261e+01]
#            x: [ 8.157e-28]
#         cost: 4287.880025129669
#          jac: [[ 4.970e+05]]
#         grad: [ 4.603e+07]
#   optimality: 3.754522317112035e-20
#  active_mask: [-1]
#         nfev: 8
#         njev: 8
# Considered failure.
# True: Te=0.165, n0=2.7e-04, Zbar_0=0.263
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 6.971e-02]
#            x: [ 4.941e-324]
#         cost: 0.002429723816477551
#          jac: [[ 9.938e+02]]
#         grad: [ 6.928e+01]
#   optimality: 3.4e-322
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.173, n0=2.7e-04, Zbar_0=0.263
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.318e-01]
#            x: [ 1.040e-27]
#         cost: 0.008686520844658773
#          jac: [[ 1.752e+03]]
#         grad: [ 2.310e+02]
#   optimality: 2.401669199353497e-25
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.181, n0=2.7e-04, Zbar_0=0.263
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.436e-01]
#            x: [ 1.146e-30]
#         cost: 0.029682211999241807
#          jac: [[ 3.021e+03]]
#         grad: [ 7.361e+02]
#   optimality: 8.437723106393262e-28
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.190, n0=2.7e-04, Zbar_0=0.263
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.408e-01]
#            x: [ 2.132e-30]
#         cost: 0.09714058240478514
#          jac: [[ 5.097e+03]]
#         grad: [ 2.247e+03]
#   optimality: 4.790569334748698e-27
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# Considered failure.
# True: Te=0.199, n0=2.7e-04, Zbar_0=0.263
# ...
#          jac: [[ 7.319e-08]]
#         grad: [ 1.117e-23]
#   optimality: 4.1586664006022396e-24
#  active_mask: [0]
#         nfev: 64
#         njev: 64
# Considered failure.
# True: Te=0.004, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.557e-16]
#            x: [ 3.823e-01]
#         cost: 1.2123775700697971e-32
#          jac: [[ 7.959e-08]]
#         grad: [ 1.239e-23]
#   optimality: 4.737879322882019e-24
#  active_mask: [0]
#         nfev: 64
#         njev: 64
# Considered failure.
# True: Te=0.004, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.593e-16]
#            x: [ 3.926e-01]
#         cost: 1.2684343255738348e-32
#          jac: [[ 8.674e-08]]
#         grad: [ 1.382e-23]
#   optimality: 5.4233770156711184e-24
#  active_mask: [0]
#         nfev: 64
#         njev: 64
# Considered failure.
# True: Te=0.004, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.634e-16]
#            x: [ 4.030e-01]
#         cost: 1.3346398089236572e-32
#          jac: [[ 9.474e-08]]
#         grad: [ 1.548e-23]
#   optimality: 6.237626776150857e-24
#  active_mask: [0]
#         nfev: 64
#         njev: 64
# Considered failure.
# True: Te=0.005, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.681e-16]
#            x: [ 4.136e-01]
#         cost: 1.4123288194409432e-32
#          jac: [[ 1.037e-07]]
#         grad: [ 1.743e-23]
#   optimality: 7.208446365130585e-24
#  active_mask: [0]
#         nfev: 64
#         njev: 64
# Considered failure.
# True: Te=0.005, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.283e-16]
#            x: [ 4.243e-01]
#         cost: 5.389609983368109e-32
#          jac: [[ 1.338e-07]]
#         grad: [ 4.391e-23]
#   optimality: 1.863341172669852e-23
#  active_mask: [0]
#         nfev: 63
#         njev: 63
# Considered failure.
# True: Te=0.005, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.342e-16]
#            x: [ 4.352e-01]
#         cost: 5.584837510777696e-32
#          jac: [[ 1.460e-07]]
#         grad: [ 4.879e-23]
#   optimality: 2.12316125778284e-23
#  active_mask: [0]
#         nfev: 63
#         njev: 63
# Considered failure.
# True: Te=0.005, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.413e-16]
#            x: [ 4.462e-01]
#         cost: 5.824810996971312e-32
#          jac: [[ 1.597e-07]]
#         grad: [ 5.451e-23]
#   optimality: 2.4326153319456253e-23
#  active_mask: [0]
#         nfev: 63
#         njev: 63
# Considered failure.
# True: Te=0.006, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.497e-16]
#            x: [ 4.574e-01]
#         cost: 6.114907544583638e-32
#          jac: [[ 1.752e-07]]
#         grad: [ 6.128e-23]
#   optimality: 2.8027062689207057e-23
#  active_mask: [0]
#         nfev: 63
#         njev: 63
# Considered failure.
# True: Te=0.006, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.595e-16]
#            x: [ 4.687e-01]
#         cost: 6.461789425591321e-32
#          jac: [[ 1.927e-07]]
#         grad: [ 6.928e-23]
#   optimality: 3.247203230663478e-23
#  active_mask: [0]
#         nfev: 63
#         njev: 63
# Considered failure.
# True: Te=0.006, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.708e-16]
#            x: [ 4.801e-01]
#         cost: 6.873661422002753e-32
#          jac: [[ 2.125e-07]]
#         grad: [ 7.881e-23]
#   optimality: 3.783410557448749e-23
#  active_mask: [0]
#         nfev: 63
#         njev: 63
# Considered failure.
# True: Te=0.006, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.401e-16]
#            x: [ 4.916e-01]
#         cost: 2.7390188956483372e-31
#          jac: [[ 2.787e-07]]
#         grad: [ 2.063e-22]
#   optimality: 1.0142092631654481e-22
#  active_mask: [0]
#         nfev: 62
#         njev: 62
# Considered failure.
# True: Te=0.007, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.550e-16]
#            x: [ 5.032e-01]
#         cost: 2.8498863149481867e-31
#          jac: [[ 3.065e-07]]
#         grad: [ 2.314e-22]
#   optimality: 1.1643686710520423e-22
#  active_mask: [0]
#         nfev: 62
#         njev: 62
# Considered failure.
# True: Te=0.007, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.730e-16]
#            x: [ 5.149e-01]
#         cost: 2.9875273724373773e-31
#          jac: [[ 3.380e-07]]
#         grad: [ 2.613e-22]
#   optimality: 1.3454367226374122e-22
#  active_mask: [0]
#         nfev: 62
#         njev: 62
# Considered failure.
# True: Te=0.007, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.944e-16]
#            x: [ 5.267e-01]
#         cost: 3.155565178053035e-31
#          jac: [[ 3.740e-07]]
#         grad: [ 2.971e-22]
#   optimality: 1.564826388391993e-22
#  active_mask: [0]
#         nfev: 62
#         njev: 62
# Considered failure.
# True: Te=0.008, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 8.196e-16]
#            x: [ 5.385e-01]
#         cost: 3.358538204527722e-31
#          jac: [[ 4.151e-07]]
#         grad: [ 3.402e-22]
#   optimality: 1.8319704321837526e-22
#  active_mask: [0]
#         nfev: 62
#         njev: 62
# Considered failure.
# True: Te=0.008, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.691e-15]
#            x: [ 5.504e-01]
#         cost: 1.4297087147226984e-30
#          jac: [[ 5.568e-07]]
#         grad: [ 9.415e-22]
#   optimality: 5.181908115474408e-22
#  active_mask: [0]
#         nfev: 61
#         njev: 61
# Considered failure.
# True: Te=0.008, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.724e-15]
#            x: [ 5.623e-01]
#         cost: 1.4856633979480445e-30
#          jac: [[ 6.159e-07]]
#         grad: [ 1.062e-21]
#   optimality: 5.969653072550658e-22
#  active_mask: [0]
#         nfev: 61
#         njev: 61
# Considered failure.
# True: Te=0.009, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.765e-15]
#            x: [ 5.743e-01]
#         cost: 1.5570611154699764e-30
#          jac: [[ 6.837e-07]]
#         grad: [ 1.207e-21]
#   optimality: 6.928817662897799e-22
#  active_mask: [0]
#         nfev: 61
#         njev: 61
# Considered failure.
# True: Te=0.009, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.814e-15]
#            x: [ 5.863e-01]
#         cost: 1.6460593616235108e-30
#          jac: [[ 7.618e-07]]
#         grad: [ 1.382e-21]
#   optimality: 8.103016196055179e-22
#  active_mask: [0]
#         nfev: 61
#         njev: 61
# Considered failure.
# True: Te=0.010, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.874e-15]
#            x: [ 5.982e-01]
#         cost: 1.755404819875697e-30
#          jac: [[ 8.519e-07]]
#         grad: [ 1.596e-21]
#   optimality: 9.548503643717542e-22
#  active_mask: [0]
#         nfev: 61
#         njev: 61
# Considered failure.
# True: Te=0.010, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.982e-15]
#            x: [ 6.102e-01]
#         cost: 7.929437120817483e-30
#          jac: [[ 1.168e-06]]
#         grad: [ 4.653e-21]
#   optimality: 2.8391245653106114e-21
#  active_mask: [0]
#         nfev: 60
#         njev: 60
# Considered failure.
# True: Te=0.011, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.060e-15]
#            x: [ 6.221e-01]
#         cost: 8.241759524225203e-30
#          jac: [[ 1.302e-06]]
#         grad: [ 5.285e-21]
#   optimality: 3.288010577519878e-21
#  active_mask: [0]
#         nfev: 60
#         njev: 60
# Considered failure.
# True: Te=0.011, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.159e-15]
#            x: [ 6.340e-01]
#         cost: 8.650002482490182e-30
#          jac: [[ 1.457e-06]]
#         grad: [ 6.058e-21]
#   optimality: 3.840722028650167e-21
#  active_mask: [0]
#         nfev: 60
#         njev: 60
# Considered failure.
# True: Te=0.012, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.282e-15]
#            x: [ 6.458e-01]
#         cost: 9.168263173113316e-30
#          jac: [[ 1.636e-06]]
#         grad: [ 7.007e-21]
#   optimality: 4.525382533204427e-21
#  active_mask: [0]
#         nfev: 60
#         njev: 60
# Considered failure.
# True: Te=0.012, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.431e-15]
#            x: [ 6.575e-01]
#         cost: 9.81475671123304e-30
#          jac: [[ 1.846e-06]]
#         grad: [ 8.180e-21]
#   optimality: 5.378801689024984e-21
#  active_mask: [0]
#         nfev: 60
#         njev: 60
# Considered failure.
# True: Te=0.013, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.607e-15]
#            x: [ 6.692e-01]
#         cost: 1.061285436570777e-29
#          jac: [[ 2.092e-06]]
#         grad: [ 9.637e-21]
#   optimality: 6.449442597654767e-21
#  active_mask: [0]
#         nfev: 60
#         njev: 60
# Considered failure.
# True: Te=0.013, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 9.853e-15]
#            x: [ 6.808e-01]
#         cost: 4.854448254420693e-29
#          jac: [[ 2.907e-06]]
#         grad: [ 2.864e-20]
#   optimality: 1.9496228430456604e-20
#  active_mask: [0]
#         nfev: 59
#         njev: 59
# Considered failure.
# True: Te=0.014, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.463e-05]
#            x: [ 6.929e-01]
#         cost: 9.960970688887048e-10
#          jac: [[ 1.283e-01]]
#         grad: [ 5.727e-06]
#   optimality: 3.968018458402754e-06
#  active_mask: [0]
#         nfev: 69
#         njev: 56
# Considered failure.
# True: Te=0.015, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.746e-03]
#            x: [ 7.075e-01]
#         cost: 1.5241769521049933e-06
#          jac: [[ 8.929e-01]]
#         grad: [ 1.559e-03]
#   optimality: 0.0011029131423504345
#  active_mask: [0]
#         nfev: 60
#         njev: 47
# Considered failure.
# True: Te=0.015, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.782e-03]
#            x: [ 7.222e-01]
#         cost: 3.0277267828838085e-05
#          jac: [[ 2.110e+00]]
#         grad: [ 1.642e-02]
#   optimality: 0.011859767857256034
#  active_mask: [0]
#         nfev: 63
#         njev: 49
# Considered failure.
# True: Te=0.016, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.225e-02]
#            x: [ 7.372e-01]
#         cost: 0.0002474235087324364
#          jac: [[ 4.021e+00]]
#         grad: [ 8.945e-02]
#   optimality: 0.0659463704104139
#  active_mask: [0]
#         nfev: 68
#         njev: 50
# Considered failure.
# True: Te=0.017, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.233e-02]
#            x: [ 7.524e-01]
#         cost: 0.0013691511226372366
#          jac: [[ 7.005e+00]]
#         grad: [ 3.666e-01]
#   optimality: 0.2758230357210774
#  active_mask: [0]
#         nfev: 65
#         njev: 49
# Considered failure.
# True: Te=0.018, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.106e-01]
#            x: [ 7.678e-01]
#         cost: 0.006115990193208805
#          jac: [[ 1.006e+01]]
#         grad: [ 1.113e+00]
#   optimality: 0.8546543925839631
#  active_mask: [0]
#         nfev: 62
#         njev: 45
# Considered failure.
# True: Te=0.019, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.190e-01]
#            x: [ 7.834e-01]
#         cost: 0.02398940147261512
#          jac: [[ 7.947e+00]]
#         grad: [ 1.741e+00]
#   optimality: 1.3637697216605658
#  active_mask: [0]
#         nfev: 61
#         njev: 46
# Considered failure.
# True: Te=0.019, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.164e-01]
#            x: [ 7.993e-01]
#         cost: 0.08670956363017762
#          jac: [[ 3.074e+01]]
#         grad: [ 1.280e+01]
#   optimality: 10.229886308266579
#  active_mask: [0]
#         nfev: 62
#         njev: 46
# Considered failure.
# True: Te=0.020, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.722e-01]
#            x: [ 8.153e-01]
#         cost: 0.2981318035607013
#          jac: [[ 4.976e+01]]
#         grad: [ 3.842e+01]
#   optimality: 31.32675725179841
#  active_mask: [0]
#         nfev: 57
#         njev: 43
# Considered failure.
# True: Te=0.021, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.413e+00]
#            x: [ 8.316e-01]
#         cost: 0.9984891261307495
#          jac: [[ 8.143e+01]]
#         grad: [ 1.151e+02]
#   optimality: 95.68551599070614
#  active_mask: [0]
#         nfev: 63
#         njev: 48
# Considered failure.
# True: Te=0.022, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.578e+00]
#            x: [ 8.481e-01]
#         cost: 3.3236707619503596
#          jac: [[ 2.271e+01]]
#         grad: [ 5.855e+01]
#   optimality: 49.64989548952381
#  active_mask: [0]
#         nfev: 61
#         njev: 45
# Considered failure.
# True: Te=0.023, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.736e+00]
#            x: [ 8.648e-01]
#         cost: 11.213265701072729
#          jac: [[ 2.336e+02]]
#         grad: [ 1.106e+03]
#   optimality: 956.7346249775737
#  active_mask: [0]
#         nfev: 56
#         njev: 41
# Considered failure.
# True: Te=0.025, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 8.853e+00]
#            x: [ 8.817e-01]
#         cost: 39.18876021082479
#          jac: [[ 4.193e+02]]
#         grad: [ 3.712e+03]
#   optimality: 3272.5886183513207
#  active_mask: [0]
#         nfev: 63
#         njev: 50
# Considered failure.
# True: Te=0.026, n0=2.7e-04, Zbar_0=1.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.708e+01]
#            x: [ 8.989e-01]
#         cost: 145.8648910625574
#          jac: [[ 7.998e+02]]
#         grad: [ 1.366e+04]
#   optimality: 12278.797281034678
#  active_mask: [0]
#         nfev: 56
#         njev: 40

# %%
fig, ax = plt.subplots(figsize=(10,6))

# colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

colors = plt.cm.plasma(np.linspace(0, 1,len(Saha_list))) #plt.cycler("color", plt.cm.jet(np.linspace(0,1,len(Saha_list))))



ax.set_ylabel(r"$\langle Z \rangle$")#,color=colors[0])
ax.set_xlabel("T [K]")
ax.set_xscale('log')

ax2 = ax.twinx()
# ax2.plot(T_K_array, Δχ_Saha*AU_to_eV,'--.',color=colors[1])
ax2.set_ylabel(r"$\Delta \chi$ [eV]")#,color=colors[1])

for i, (Zbar_0, Saha) in enumerate(zip(Zbar_0_list, Saha_list)):
    if i==0:
        try:
            ax.plot(T_K_array, Saha[0],'-' , color=colors[i], label=f'Initial guess, Zbar= {Zbar_0:0.3f}')
            ax2.plot(T_K_array, Saha[1]*AU_to_eV,':' , color=colors[i], label=r'$\chi_0$')
        except TypeError:
            pass
            
    else:
        try:
            ax.plot(T_K_array, Saha[0],'-' , color=colors[i])#, label=f'Initial guess, Zbar= {Zbar_0:0.3f}')
            ax2.plot(T_K_array, Saha[1]*AU_to_eV,':' , color=colors[i])
        except TypeError:
            pass
            
# ax2.plot(T_K_array, Δχ_Saha_1*AU_to_eV,'-' ,color=colors[1])

ax2.plot(T_K_array, np.ones_like(T_K_array)*χ0_AU*AU_to_eV,'-' ,color='k')
ax2.text(np.min(T_K_array)*1.2, 1.01*χ0_AU*AU_to_eV, r"$\chi_0$ = {0:0.1f} [eV]".format(χ0_AU*AU_to_eV), fontsize=12,
        verticalalignment='bottom')#, bbox=props)

# Adding a manual colorbar
sm = plt.cm.ScalarMappable(cmap='plasma', norm=plt.Normalize(vmin=0, vmax=1))
sm.set_array([])
fig.colorbar(sm, ax=[ax, ax2], orientation='vertical', label=r'$\langle Z\rangle^{\rm initial guess}$')

plt.subplots_adjust(right=0.7)

# text
props = dict(boxstyle='round', facecolor='white', alpha=0.5)
inset_text = f"{element} at n = {n0_invcc:0.2e} [1/cc]"
ax.text(0.15, 0.95, inset_text, transform=ax.transAxes, fontsize=12,
        verticalalignment='top', bbox=props)

ax.set_ylim(1e-4,1.2)
ax2.set_ylim(1e-4,1.2*χ0_AU*AU_to_eV)

ax.set_yscale('log')
ax2.set_yscale('log')
ax.legend()
# plt.tight_layout()

# ax.set_yscale('log')

# %%
# Fix nan, None issues...

Zbar_list = np.array([Saha[0] for Saha in Saha_list])
χ0_list   = np.array([Saha[1] for Saha in Saha_list])
Zbar_mean, Zbar_std = np.nanmean(Zbar_list,axis=0), np.nanstd(Zbar_list,axis=0) 
χ0_mean, χ0_std = np.nanmean(χ0_list,axis=0), np.nanstd(χ0_list,axis=0)

# %%
fig, ax = plt.subplots(figsize=(10,6))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

ax.set_ylabel(r"$\langle Z \rangle$",color=colors[0])
ax.set_xlabel("T [K]")
ax.set_xscale('log')

ax2 = ax.twinx()
ax2.set_ylabel(r"$\Delta \chi$ [eV]",color=colors[1])

# Plot mean and Std
ax.plot(T_K_array, Zbar_mean,'-' , color=colors[0])#, label=f'Initial guess')
ax.fill_between(T_K_array, Zbar_mean - Zbar_std, Zbar_mean + Zbar_std, color=colors[0], alpha=0.2)
ax2.plot(T_K_array, χ0_mean*AU_to_eV,'-' , color=colors[1])#, label=r'$\chi_0$')
ax2.fill_between(T_K_array, (χ0_mean - χ0_std)*AU_to_eV, (χ0_mean + χ0_std)*AU_to_eV, color=colors[1], alpha=0.2, linestyle='-')
           

# Plot all actual solution output    
colors = plt.cm.plasma(np.linspace(0, 1,len(Saha_list))) #plt.cycler("color", plt.cm.jet(np.linspace(0,1,len(Saha_list))))

for i, (Zbar_0, Saha) in enumerate(zip(Zbar_0_list, Saha_list)):
    if i==0:
        try:
            ax.plot(T_K_array, Saha[0],'^' , color=colors[i], label=f'Solution for colorbar initial guess', alpha=0.1, markersize=5)
            ax2.plot(T_K_array, Saha[1]*AU_to_eV,'^' , color=colors[i], label=r'$\chi_0$', alpha=0.1, markersize=5)
        except TypeError:
            pass
            
    else:
        try:
            ax.plot(T_K_array, Saha[0],'^' , color=colors[i],alpha=0.1, markersize=5)
            ax2.plot(T_K_array, Saha[1]*AU_to_eV,'^' , color=colors[i],alpha=0.1, markersize=5)
        except TypeError:
            pass


# Plot χ0 Line
ax2.plot(T_K_array, np.ones_like(T_K_array)*χ0_AU*AU_to_eV,'-' ,color='k')
ax2.text(np.min(T_K_array)*1.2, 1.01*χ0_AU*AU_to_eV, r"$\chi_0$ = {0:0.1f} [eV]".format(χ0_AU*AU_to_eV), fontsize=12,
        verticalalignment='bottom')#, bbox=props)

# Adding a manual colorbar
sm = plt.cm.ScalarMappable(cmap='plasma', norm=plt.Normalize(vmin=0, vmax=1))
sm.set_array([])
fig.colorbar(sm, ax=[ax, ax2], orientation='vertical', label=r'$\langle Z\rangle^{\rm initial guess}$')

plt.subplots_adjust(right=0.7)

# text
props = dict(boxstyle='round', facecolor='white', alpha=0.5)
inset_text = f"{element} at n = {n0_invcc:0.2e} [1/cc]"
ax.text(0.15, 0.95, inset_text, transform=ax.transAxes, fontsize=12,
        verticalalignment='top', bbox=props)

ax.set_ylim(1e-7,10)
ax2.set_ylim(1e-3,10*χ0_AU*AU_to_eV)

ax.set_yscale('log')
ax2.set_yscale('log')
ax.legend()
# plt.tight_layout()

# ax.set_yscale('log')

# %%
# Ion density
n0_invcc_array = n0_invcc*np.geomspace(0.5,1.5,num=10) 

# Temperature
T_K_array = np.geomspace(5e2, 7e4, num=100)

n_invcc_mesh, T_K_mesh = np.meshgrid(n0_invcc_array, T_K_array, indexing='ij')

Zbar_0_list = np.linspace(5e-6,1-1e-6, num=8)
Saha_array = np.array([ solve_Saha(T_K_mesh*K_to_AU, n_invcc_mesh*invcc_to_AU, Zbar_0=Zbar_0) for Zbar_0 in Zbar_0_list] )

# %%
Zbar_mean
# Out:
# array([8.61880418e-09, 8.62101220e-09, 8.62101878e-09, 8.62101882e-09,
#        8.62101883e-09, 8.62101883e-09, 8.63514650e-09, 8.64009892e-09,
#        8.64015732e-09, 8.64015861e-09, 8.64015865e-09, 8.64015865e-09,
#        8.64745639e-09, 8.64858219e-09, 8.64863078e-09, 8.64863390e-09,
#        8.64863418e-09, 8.64551667e-09, 8.64810431e-09, 8.64830631e-09,
#        8.64832915e-09, 8.63760442e-09, 8.63858727e-09, 8.64065642e-09,
#        8.64093984e-09, 8.64099195e-09, 8.64129915e-09, 8.64971539e-09,
#        8.65090369e-09, 8.65116880e-09, 8.65553391e-09, 8.65035960e-09,
#        8.65256983e-09, 8.65315012e-09, 8.65096481e-09, 8.64601268e-09,
#        8.64849006e-09, 8.64927147e-09, 8.64965767e-09, 8.65834960e-09,
#        8.64889465e-09, 8.71063714e-09, 9.10671116e-09, 1.15028953e-08,
#        2.10701540e-08, 4.66965255e-08, 1.05437080e-07, 2.32773826e-07,
#        4.98553900e-07, 1.03498395e-06, 2.08351493e-06, 4.07339537e-06,
#        7.74217635e-06, 1.43250240e-05, 2.58353561e-05, 4.54732499e-05,
#        7.82059145e-05, 1.31569671e-04, 2.16755653e-04, 3.50045157e-04,
#        5.54666661e-04, 8.63146722e-04, 1.32022301e-03, 1.98637557e-03,
#        2.94201332e-03, 4.29232373e-03, 6.17275665e-03, 8.75506975e-03,
#        1.22538192e-02, 1.69331390e-02, 2.31136276e-02, 3.11791466e-02,
#        4.15833344e-02, 5.48556048e-02, 7.16062613e-02, 9.25298943e-02,
#        1.18405089e-01, 1.50085699e-01, 1.88472847e-01, 2.34443931e-01,
#        2.88690377e-01, 3.51380855e-01, 4.21564665e-01, 4.96432101e-01,
#        5.71153111e-01, 6.40305789e-01, 7.00239264e-01, 7.50042784e-01,
#        7.90663507e-01, 8.23687684e-01, 8.50656707e-01, 8.72844726e-01,
#        8.91244650e-01, 9.06616675e-01, 9.19543194e-01, 9.30474350e-01,
#        9.39762235e-01, 9.47685814e-01, 9.54468823e-01, 9.60292734e-01])

# %%
# Fix nan, None issues...

Zbar_list = Saha_array[:,0]#np.array([Saha[0] for Saha in Saha_list])
χ0_list   = Saha_array[:,1]#np.array([Saha[1] for Saha in Saha_list])
# Zbar_mean, Zbar_std = np.nanmean(Zbar_list,axis=0), np.nanstd(Zbar_list,axis=0) 
# χ0_mean, χ0_std = np.nanmean(χ0_list,axis=0), np.nanstd(χ0_list,axis=0) 

Zbar_mean = np.nanmean(Zbar_list,axis=0)
χ0_mean = np.nanmean(χ0_list,axis=0)

# %%
mesh_save_data = np.array( [ n_invcc_mesh.flatten(), T_K_mesh.flatten(), Zbar_mean.flatten(), χ0_mean.flatten()*AU_to_eV ]).T
header = ("# Shown is also the standard deviation from a large set of initial guesses, if large then invalid- multiple solutions \n" + 
            "   n[1/cc]      T[K]         Zbar         χ0[eV]")
savename = f"{element}_Saha.txt"
np.savetxt(savename, mesh_save_data, header = header , fmt ="%12.3e", comments='')
